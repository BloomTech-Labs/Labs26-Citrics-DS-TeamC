# %% [markdown]
# <a href="https://colab.research.google.com/github/Lambda-School-Labs/Labs26-Citrics-DS-TeamC/blob/fatai_king/Weather_Geo_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
dos = pd.read_csv('/content/drive/My Drive/driftly labs folder/weather_df_final.csv')
df = pd.read_csv('/content/drive/My Drive/driftly labs folder/uscities.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#           city  ...          id
# 0     New York  ...  1840034016
# 1  Los Angeles  ...  1840020491
# 2      Chicago  ...  1840000494
# 3        Miami  ...  1840015149
# 4       Dallas  ...  1840019440
#
# [5 rows x 17 columns]

# %%
df.shape
# Out:
# (29488, 17)

# %%
dos.head()
# Out:
#    Unnamed: 0        City Postal      City_State  ...  year  month  day   date_time
# 0           0  Alpharetta     GA  Alpharetta, GA  ...  2015      1    1  2015-01-01
# 1           1  Alpharetta     GA  Alpharetta, GA  ...  2015      1    2  2015-01-02
# 2           2  Alpharetta     GA  Alpharetta, GA  ...  2015      1    3  2015-01-03
# 3           3  Alpharetta     GA  Alpharetta, GA  ...  2015      1    4  2015-01-04
# 4           4  Alpharetta     GA  Alpharetta, GA  ...  2015      1    5  2015-01-05
#
# [5 rows x 26 columns]

# %%
dos.shape
# Out:
# (1215202, 26)

# %%
df.shape
# Out:
# (29488, 17)

# %%
dos.drop(columns='Unnamed: 0', inplace=True)

# %% [markdown]
# # **Created City_Postal Column for both datasets**

# %%
dos['city_postal'] = dos['City'] + '_' + dos['Postal']
print(dos.head())
# Out:
#          City Postal      City_State  ...  day   date_time    city_postal
# 0  Alpharetta     GA  Alpharetta, GA  ...    1  2015-01-01  Alpharetta_GA
# 1  Alpharetta     GA  Alpharetta, GA  ...    2  2015-01-02  Alpharetta_GA
# 2  Alpharetta     GA  Alpharetta, GA  ...    3  2015-01-03  Alpharetta_GA
# 3  Alpharetta     GA  Alpharetta, GA  ...    4  2015-01-04  Alpharetta_GA
# 4  Alpharetta     GA  Alpharetta, GA  ...    5  2015-01-05  Alpharetta_GA
#
# [5 rows x 26 columns]

# %%
df['city_postal'] = df['city'] + '_' + df['state_id']
print(df.head())
# Out:
#           city   city_ascii  ...          id     city_postal
# 0     New York     New York  ...  1840034016     New York_NY
# 1  Los Angeles  Los Angeles  ...  1840020491  Los Angeles_CA
# 2      Chicago      Chicago  ...  1840000494      Chicago_IL
# 3        Miami        Miami  ...  1840015149        Miami_FL
# 4       Dallas       Dallas  ...  1840019440       Dallas_TX
#
# [5 rows x 18 columns]

# %%
dos['city_postal'].value_counts()
# Out:
# Honolulu_HI          1823
# El Monte_CA          1822
# Buena Park_CA        1822
# Santa Maria_CA       1822
# San Marcos_CA        1822
#                      ...
# Spokane_WA           1675
# Coeur d'Alene_ID     1665
# Carson City_NV       1664
# Spokane Valley_WA    1659
# Juneau_AK            1619
# Name: city_postal, Length: 687, dtype: int64

# %%
df['city_postal'].value_counts()
# Out:
# Midway_FL                     3
# Oakland_PA                    3
# Georgetown_PA                 3
# Chula Vista_TX                3
# Oakwood_OH                    3
#                              ..
# Fairfield_NC                  1
# Cordry Sweetwater Lakes_IN    1
# Millville_PA                  1
# Mineral_IL                    1
# Port Jefferson Station_NY     1
# Name: city_postal, Length: 29319, dtype: int64

# %%
df.head()
# Out:
#           city   city_ascii  ...          id     city_postal
# 0     New York     New York  ...  1840034016     New York_NY
# 1  Los Angeles  Los Angeles  ...  1840020491  Los Angeles_CA
# 2      Chicago      Chicago  ...  1840000494      Chicago_IL
# 3        Miami        Miami  ...  1840015149        Miami_FL
# 4       Dallas       Dallas  ...  1840019440       Dallas_TX
#
# [5 rows x 18 columns]

# %%
dos.head()
# Out:
#          City Postal      City_State  ...  day   date_time    city_postal
# 0  Alpharetta     GA  Alpharetta, GA  ...    1  2015-01-01  Alpharetta_GA
# 1  Alpharetta     GA  Alpharetta, GA  ...    2  2015-01-02  Alpharetta_GA
# 2  Alpharetta     GA  Alpharetta, GA  ...    3  2015-01-03  Alpharetta_GA
# 3  Alpharetta     GA  Alpharetta, GA  ...    4  2015-01-04  Alpharetta_GA
# 4  Alpharetta     GA  Alpharetta, GA  ...    5  2015-01-05  Alpharetta_GA
#
# [5 rows x 26 columns]

# %%
df.dtypes
# Out:
# city             object
# city_ascii       object
# state_id         object
# state_name       object
# county_fips       int64
# county_name      object
# lat             float64
# lng             float64
# population      float64
# density         float64
# source           object
# military           bool
# incorporated       bool
# timezone         object
# ranking           int64
# zips             object
# id                int64
# city_postal      object
# dtype: object

# %%
both['City'].nunique()
# Out:
# 683

# %%
dos['City'].nunique()
# Out:
# 684

# %% [markdown]
# # **Loaded in our List of cities we have, want to make sure all cities are inside the other dataset**

# %%
our_list= ['Alpharetta_GA', 'Allentown_PA', 'Allen_TX', 'Aliso Viejo_CA', 'Alhambra_CA', 'Alexandria_VA', 'Albuquerque_NM', 'Albany_NY', 'Alameda_CA', 'Akron_OH', 'Austin_TX', 
           'Aurora_CO', 'Augusta_ME', 'Auburn_WA', 'Atlanta_GA', 'Asheville_NC', 'Arvada_CO', 'Arlington_TX', 'Arcadia_CA', 'Apple Valley_MN', 'Appleton_WI', 'Apopka_FL', 'Antioch_CA',
           'Ann Arbor_MI', 'Annapolis_MD', 'Ankeny_IA', 'Anderson_IN', 'Anaheim_CA', 'Ames_IA', 'Amarillo_TX', 'Boulder_CO', 'Boston_MA', 'Bossier City_LA', 'Bonita Springs_FL', 'Boise_ID', 
           'Boca Raton_FL', 'Blue Springs_MO', 'Bloomington_IN', 'Blaine_MN', 'Bismarck_ND', 'Birmingham_AL', 'Billings_MT', 'Bethlehem_PA', 'Berwyn_IL', 'Berkeley_CA', 'Bentonville_AR', 'Bend_OR',
           'Bellingham_WA', 'Bellflower_CA', 'Bellevue_WA', 'Beaverton_OR', 'Baytown_TX', 'Bayonne_NJ', 'Battle Creek_MI', 'Baton Rouge_LA', 'Bartlett_TN', 'Baltimore_MD', 'Baldwin Park_CA', 'Bakersfield_CA',
           'Avondale_AZ', 'Chino Hills_CA', 'Chino_CA', 'Chicopee_MA', 'Chico_CA', 'Chicago_IL', 'Chesapeake_VA', 'Cheyenne_WY', 'Chattanooga_TN', 'Charlotte_NC', 'Charleston_WV', 'Charleston_SC', 
           'Chandler_AZ', 'Champaign_IL', 'Centennial_CO', 'Cedar Rapids_IA', 'Cedar Park_TX', 'Cathedral City_CA', 'Casa Grande_AZ', 'Casper_WY', 'Carson City_NV', 'Carson_CA', 'Carrollton_TX', 'Carmel_IN', 
           'Carlsbad_CA', 'Canton_OH', 'Cape Coral_FL', 'Camden_NJ', 'Cambridge_MA', 'Camarillo_CA', 'Caldwell_ID', 'Burnsville_MN', 'Burlington_NC', 'Burien_WA', 'Burbank_CA', 'Buffalo_NY', 'Buena Park_CA',
           'Buckeye_AZ', 'Bryan_TX', 'Brownsville_TX', 'Broomfield_CO', 'Brooklyn Park_MN', 'Brookhaven_GA', 'Broken Arrow_OK', 'Brockton_MA', 'Bristol_CT', 'Bridgeport_CT', 'Brentwood_CA', 'Bradenton_FL', 
           'Boynton Beach_FL', 'Bowling Green_KY', 'Bowie_MD', 'Flint_MI', 'Flagstaff_AZ', 'Fishers_IN', 'Federal Way_WA', 'Fayetteville_NC', 'Farmington Hills_MI', 'Fall River_MA', 'Fairfield_CA', 
           'Everett_WA', 'Evansville_IN', 'Evanston_IL', 'Euless_TX', 'Escondido_CA', 'Erie_PA', 'Elyria_OH', 'El Paso_TX', 'Encinitas_CA', 'El Monte_CA', 'Elk Grove_CA', 'Elkhart_IN', 'Elizabeth_NJ', 
           'Elgin_IL', 'El Cajon_CA', 'Edmond_OK', 'Edinburg_TX', 'Edina_MN', 'Eden Prairie_MN', 'Eau Claire_WI', 'Eastvale_CA', 'East Orange_NJ', 'Eagan_MN', 'Durham_NC', 'Duluth_MN', 'Dubuque_IA',
           'Dublin_CA', 'Downey_CA', 'Dover_DE', 'Dothan_AL', 'Doral_FL', 'Diamond Bar_CA', 'Detroit_MI', 'Des Plaines_IL', 'DeSoto_TX', 'Des Moines_IA', 'Denver_CO', 'Denton_TX', 'Deltona_FL',
           'Delray Beach_FL', 'Delano_CA', 'Deerfield Beach_FL', 'Decatur_IL', 'Dearborn Heights_MI', 'Daytona Beach_FL', 'Dearborn_MI', 'Davis_CA', 'Davenport_IA', 'Dayton_OH', 'Danbury_CT', 
           'Daly City_CA', 'Dallas_TX', 'Cupertino_CA', 'Cranston_RI', 'Council Bluffs_IA', 'Costa Mesa_CA', 'Corvallis_OR', 'Corpus Christi_TX', 'Corona_CA', 'Coral Springs_FL', 'Coon Rapids_MN', 
           'Conway_AR', 'Conroe_TX', 'Concord_NH', 'Concord_CA', 'Commerce City_CO', 'Columbus_OH', 'Columbia_SC', 'Colton_CA', 'Colorado Springs_CO', 'College Station_TX', "Coeur d'Alene_ID",
           'Coconut Creek_FL', 'Clovis_CA', 'Clifton_NJ', 'Cleveland_OH', 'Clearwater_FL', 'Clarksville_TN', 'Citrus Heights_CA', 'Cincinnati_OH', 'Chula Vista_CA', 'Hartford_CT', 'Harrisonburg_VA',
           'Harrisburg_PA', 'Harlingen_TX', 'Hanford_CA', 'Hammond_IN', 'Hamilton_OH', 'Gulfport_MS', 'Gresham_OR', 'Greenwood_IN', 'Greenville_NC', 'Greensboro_NC', 'Green Bay_WI', 'Greeley_CO',
           'Great Falls_MT', 'Grapevine_TX', 'Grand Rapids_MI', 'Grand Prairie_TX', 'Grand Junction_CO', 'Grand Island_NE', 'Grand Forks_ND', 'Goodyear_AZ', 'Glendora_CA', 'Glendale_AZ', 'Gilroy_CA',
           'Georgetown_TX', 'Gastonia_NC', 'Gary_IN', 'Garland_TX', 'Gardena_CA', 'Galveston_TX', 'Gaithersburg_MD', 'Gainesville_FL', 'Fullerton_CA', 'Frisco_TX', 'Fresno_CA', 'Fremont_CA', 'Frederick_MD', 
           'Franklin_TN', 'Frankfort_KY', 'Framingham_MA', 'Fountain Valley_CA', 'Fort Worth_TX', 'Fort Wayne_IN', 'Fort Smith_AR', 'Fort Myers_FL', 'Fort Lauderdale_FL', 'Folsom_CA', 'Fontana_CA', 
           'Florissant_MO', 'Lubbock_TX', 'Lowell_MA', 'Loveland_CO', 'Los Angeles_CA', 'Lorain_OH', 'Longview_TX', 'Long Beach_CA', 'Longmont_CO', 'Logan_UT', 'Lodi_CA', 'Livonia_MI', 'Livermore_CA',
           'Little Rock_AR', 'Little Elm_TX', 'Lincoln_NE', 'Lewisville_TX', 'Lenexa_KS', 'Lehi_UT', "Lee's Summit_MO", 'Leander_TX', 'League City_TX', 'Layton_UT', 'Lawton_OK', 'Lawrence_KS', 
           'Lauderhill_FL', 'Las Vegas_NV', 'Las Cruces_NM', 'Largo_FL', 'Laredo_TX', 'Lansing_MI', 'La Mesa_CA', 'Lancaster_CA', 'Lakewood_CO', 'Lakeville_MN', 'Lake Havasu City_AZ', 'Lakeland_FL', 
           'Lake Forest_CA', 'Lake Charles_LA', 'Lake Elsinore_CA', 'La Habra_CA', 'Laguna Niguel_CA', 'Lafayette_LA', 'La Crosse_WI', 'Lacey_WA', 'Kokomo_IN', 'Knoxville_TN', 'Kirkland_WA', 
           'Kissimmee_FL', 'Kingsport_TN', 'Killeen_TX', 'Kettering_OH', 'Kentwood_MI', 'Kent_WA', 'Kenosha_WI', 'Kennewick_WA', 'Kenner_LA', 'Kansas City_MO', 'Kannapolis_NC', 'Kalamazoo_MI',
           'Jurupa Valley_CA', 'Juneau_AK', 'Joplin_MO', 'Jonesboro_AR', 'Joliet_IL', 'Johnson City_TN', 'Johns Creek_GA', 'Jersey City_NJ', 'Jefferson City_MO', 'Janesville_WI', 'Jacksonville_FL',
           'Jackson_MS', 'Irving_TX', 'Irvine_CA', 'Iowa City_IA', 'Inglewood_CA', 'Indio_CA', 'Indianapolis_IN', 'Idaho Falls_ID', 'Huntsville_AL', 'Huntington Park_CA', 'Huntington Beach_CA', 'Houston_TX',
           'Hoover_AL', 'Honolulu_HI', 'Homestead_FL', 'Hollywood_FL', 'Hoboken_NJ', 'High Point_NC', 'Hillsboro_OR', 'Highland_CA', 'Hialeah_FL', 'Hesperia_CA', 'Herriman_UT', 'Hendersonville_TN', 
           'Henderson_NV', 'Hayward_CA', 'Hemet_CA', 'Helena_MT', 'Hawthorne_CA', 'Haverhill_MA', 'Oceanside_CA', 'Ocala_FL', 'Oakland_CA', 'Novi_MI', 'Novato_CA', 'Norwalk_CA', 'North Richland Hills_TX',
           'North Port_FL', 'North Little Rock_AR', 'North Miami_FL', 'North Las Vegas_NV', 'North Charleston_SC', 'Norman_OK', 'Norfolk_VA', 'Noblesville_IN', 'New York_NY', 'Newton_MA', 'New Rochelle_NY', 
           'Newport News_VA', 'Newport Beach_CA', 'New Orleans_LA', 'New Haven_CT', 'New Brunswick_NJ', 'New Britain_CT', 'New Braunfels_TX', 'New Bedford_MA', 'Newark_NJ', 'National City_CA', 'Nashville_TN',
           'Nashua_NH', 'Naperville_IL', 'Napa_CA', 'Nampa_ID', 'Murfreesboro_TN', 'Muncie_IN', 'Mount Vernon_NY', 'Mountain View_CA', 'Moreno Valley_CA', 'Moore_OK', 'Montpelier_VT', 'Montgomery_AL', 
           'Monterey Park_CA', 'Montebello_CA', 'Modesto_CA', 'Mobile_AL', 'Missouri City_TX', 'Missoula_MT', 'Mission Viejo_CA', 'Mission_TX', 'Mishawaka_IN', 'Miramar_FL', 'Minnetonka_MN', 'Minneapolis_MN',
           'Milwaukee_WI', 'Milpitas_CA', 'Millcreek_UT', 'New Milford_CT', 'Midland_TX', 'Midwest City_OK', 'Miami Gardens_FL', 'Miami Beach_FL', 'Miami_FL', 'Methuen Town_MA', 'Mesquite_TX', 'Mesa_AZ', 
           'Meridian_ID', 'Meriden_CT', 'Merced_CA', 'Menifee_CA', 'Memphis_TN', 'Melbourne_FL', 'Medford_OR', 'McAllen_TX', 'McKinney_TX', 'Maricopa_AZ', 'Marietta_GA', 'Marysville_WA', 'Margate_FL', 
           'Maple Grove_MN', 'Manteca_CA', 'Mansfield_TX', 'Manhattan_KS', 'Manchester_NH', 'Malden_MA', 'Madison_WI', 'Madera_CA', 'Lynwood_CA', 'Lynn_MA', 'Lynchburg_VA', 'St. Charles_MO', 'Sacramento_CA', 
           'Royal Oak_MI', 'Rowlett_TX', 'Round Rock_TX', 'Roswell_GA', 'Roseville_CA', 'Rosemead_CA', 'Rogers_AR', 'Rocky Mount_NC', 'Rockville_MD', 'Rocklin_CA', 'Rock Hill_SC', 'Rockford_IL',
           'Rochester Hills_MI', 'Rochester_NY', 'Roanoke_VA', 'Riverside_CA', 'Rio Rancho_NM', 'Richmond_VA', 'Richland_WA', 'Richardson_TX', 'Rialto_CA', 'Revere_MA', 'Renton_WA', 'Reno_NV',
           'Redwood City_CA', 'Redondo Beach_CA', 'Redmond_WA', 'Redlands_CA', 'Redding_CA', 'Reading_PA', 'Rapid City_SD', 'Rancho Cucamonga_CA', 'Rancho Cordova_CA', 'Quincy_MA', 'Raleigh_NC', 
           'Racine_WI', 'Pueblo_CO', 'Providence_RI', 'Portsmouth_VA', 'Port St. Lucie_FL', 'Port Orange_FL', 'Portland_OR', 'Porterville_CA', 'Port Arthur_TX', 'Pontiac_MI', 'Pompano Beach_FL',
           'Pomona_CA', 'Pocatello_ID', 'Plymouth_MN', 'Pleasanton_CA', 'Plantation_FL', 'Plano_TX', 'Plainfield_NJ', 'Placentia_CA', 'Pittsburgh_PA', 'Pittsburg_CA', 'Pinellas Park_FL', 'Pierre_SD', 
           'Petaluma_CA', 'Pico Rivera_CA', 'Phoenix_AZ', 'Philadelphia_PA', 'Pharr_TX', 'Pflugerville_TX', 'Perth Amboy_NJ', 'Perris_CA', 'Peoria_AZ', 'Pensacola_FL', 'Peabody_MA', 'Pawtucket_RI',
           'Passaic_NJ', 'Pasco_WA', 'Paterson_NJ', 'Pasadena_TX', 'Parma_OH', 'Paramount_CA', 'Palo Alto_CA', 'Palm Desert_CA', 'Palmdale_CA', 'Palm Coast_FL', 'Palm Beach Gardens_FL', 'Palm Bay_FL', 
           'Oxnard_CA', 'Owensboro_KY', 'Overland Park_KS', 'Oshkosh_WI', 'Orlando_FL', 'Orem_UT', 'Orange_CA', 'Ontario_CA', 'Omaha_NE', 'Olympia_WA', 'Olathe_KS', 'Oklahoma City_OK', 'Ogden_UT',
           "O'Fallon_MO", 'Southaven_MS', 'Somerville_MA', 'Smyrna_GA', 'Sioux Falls_SD', 'Sioux City_IA', 'Simi Valley_CA', 'Shreveport_LA', 'Shoreline_WA', 'Seattle_WA', 'Shawnee_KS', 'Scranton_PA',
           'Scottsdale_AZ', 'Schenectady_NY', 'Savannah_GA', 'Sarasota_FL', 'Santee_CA', 'Santa Rosa_CA', 'Santa Monica_CA', 'Santa Maria_CA', 'Santa Fe_NM', 'Santa Cruz_CA', 'Santa Clarita_CA',
           'Santa Clara_CA', 'Santa Barbara_CA', 'Santa Ana_CA', 'San Ramon_CA', 'San Rafael_CA', 'San Mateo_CA', 'San Marcos_CA', 'San Leandro_CA', 'San Jose_CA', 'San Francisco_CA', 'Sanford_FL',
           'Sandy Springs_GA', 'Sandy_UT', 'San Diego_CA', 'San Clemente_CA', 'San Buenaventura_CA', 'San Bernardino_CA', 'San Antonio_TX', 'San Angelo_TX', 'Sammamish_WA', 'Salt Lake City_UT',
           'Salinas_CA', 'Salem_OR',
           'St. Petersburg_FL', 'St. Peters_MO', 'St. Paul_MN', 'St. Joseph_MO', 'St. George_UT', 'St. Louis_MO', 'St. Clair Shores_MI', 'St. Cloud_MN', 
           'Woodbury_MN', 'Winston-Salem_NC', 'Wichita_KS', 'Wichita Falls_TX', 'White Plains_NY', 'Whittier_CA', 'Wheaton_IL', 'Weymouth Town_MA', 'West Valley City_UT', 'West Sacramento_CA', 
           'West Palm Beach_FL', 'Weston_FL', 'Westland_MI', 'Westminster_CO', 'West Lafayette_IN', 'West Haven_CT', 'West Des Moines_IA', 'West Covina_CA', 'West Allis_WI', 'Waukesha_WI', 'Waukegan_IL',
           'Watsonville_CA', 'Waterloo_IA', 'Waterbury_CT', 'Washington_DC', 'Warwick_RI', 'Warren_MI', 'Warner Robins_GA', 'Waltham_MA', 'Walnut Creek_CA', 'Waco_TX', 'Vista_CA', 'Visalia_CA', 'Vineland_NJ',
           'Virginia Beach_VA', 'Victorville_CA', 'Victoria_TX', 'Vancouver_WA', 'Vallejo_CA', 'Valdosta_GA', 'Vacaville_CA', 'Utica_NY', 'Upland_CA', 'Union City_CA', 'Tyler_TX', 'Twin Falls_ID', 'Tustin_CA',
           'Tuscaloosa_AL', 'Turlock_CA', 'Tulsa_OK', 'Tulare_CA', 'Tucson_AZ', 'Troy_MI', 'Trenton_NJ', 'Tracy_CA', 'Torrance_CA', 'Topeka_KS', 'Toledo_OH', 'Tigard_OR', 'Thousand Oaks_CA', 'Thornton_CO', 'Texas City_TX', 'Terre Haute_IN', 'Temple_TX', 'Tempe_AZ', 'Temecula_CA', 'Taylorsville_UT', 'Taylor_MI', 'Taunton_MA', 'Tampa_FL', 'Tamarac_FL', 'Tallahassee_FL', 'Tacoma_WA', 'Syracuse_NY', 'Surprise_AZ', 'Sunrise_FL', 'Sunnyvale_CA', 'Sugar Land_TX', 'Suffolk_VA', 'Stonecrest_GA', 'Stockton_CA', 'Stillwater_OK', 'Sterling Heights_MI', 'Stamford_CT', 'Springfield_MO', 'Springfield_IL', 'Springdale_AR', 'Spokane Valley_WA', 'Spokane_WA', 'Sparks_NV', 'South San Francisco_CA', 'South Jordan_UT', 'South Gate_CA', 'South Fulton_GA', 'Southfield_MI', 'South Bend_IN']

# %%
dos[dos['city_postal']== 'New York City_NY'].index
# Out:
# Int64Index([], dtype='int64')

# %%
df[df['city_postal'].isin(our_list)].shape
# Out:
# (690, 18)

# %%
missing_city = df['city_postal'].to_list()
print(missing_city)
# Out:
# ['New York_NY', 'Los Angeles_CA', 'Chicago_IL', 'Miami_FL', 'Dallas_TX', 'Philadelphia_PA', 'Houston_TX', 'Atlanta_GA', 'Washington_DC', 'Boston_MA', 'Phoenix_AZ', 'Seattle_WA', 'San Francisco_CA', 'Detroit_MI', 'San Diego_CA', 'Minneapolis_MN', 'Tampa_FL', 'Denver_CO', 'Brooklyn_NY', 'Queens_NY', 'Riverside_CA', 'Baltimore_MD', 'Las Vegas_NV', 'Portland_OR', 'San Antonio_TX', 'St. Louis_MO', 'Sacramento_CA', 'Orlando_FL', 'San Jose_CA', 'Cleveland_OH', 'Pittsburgh_PA', 'Austin_TX', 'Cincinnati_OH', 'Kansas City_MO', 'Manhattan_NY', 'Indianapolis_IN', 'Columbus_OH', 'Charlotte_NC', 'Virginia Beach_VA', 'Bronx_NY', 'Milwaukee_WI', 'Providence_RI', 'Jacksonville_FL', 'Salt Lake City_UT', 'Nashville_TN', 'Richmond_VA', 'Memphis_TN', 'Raleigh_NC', 'New Orleans_LA', 'Louisville_KY', 'Oklahoma City_OK', 'Bridgeport_CT', 'Buffalo_NY', 'Fort Worth_TX', 'Hartford_CT', 'Tucson_AZ', 'Omaha_NE', 'El Paso_TX', 'Honolulu_HI', 'McAllen_TX', 'Albuquerque_NM', 'Birmingham_AL', 'Sarasota_FL', 'Dayton_OH', 'Rochester_NY', 'Fresno_CA', 'Allentown_PA', 'Tulsa_OK', 'Cape Coral_FL', 'Concord_CA', 'Colorado Springs_CO', 'Charleston_SC', 'Springfield_MA', 'Grand Rapids_MI', 'Mission Viejo_CA', 'Albany_NY', 'Knoxville_TN', 'Bakersfield_CA', 'Ogden_UT', 'Baton Rouge_LA', 'Akron_OH', 'New Haven_CT', 'Columbia_SC', 'Mesa_AZ', 'Palm Bay_FL', 'Provo_UT', 'Worcester_MA', 'Murrieta_CA', 'Greenville_SC', 'Wichita_KS', 'Toledo_OH', 'Staten Island_NY', 'Des Moines_IA', 'Long Beach_CA', 'Port St. Lucie_FL', 'Denton_TX', 'Madison_WI', 'Reno_NV', 'Harrisburg_PA', 'Little Rock_AR', 'Oakland_CA', 'Durham_NC', 'Winston-Salem_NC', 'Bonita Springs_FL', 'Indio_CA', 'Palm Coast_FL', 'Chattanooga_TN', 'Spokane_WA', 'Syracuse_NY', 'Lancaster_PA', 'Arlington_TX', 'Stockton_CA', 'Poughkeepsie_NY', 'Augusta_GA', 'Boise_ID', 'Oxnard_CA', 'Scranton_PA', 'Modesto_CA', 'Kissimmee_FL', 'Aurora_CO', 'Youngstown_OH', 'Fayetteville_AR', 'Anaheim_CA', 'Pensacola_FL', 'Victorville_CA', 'Lancaster_CA', 'Greensboro_NC', 'Corpus Christi_TX', 'Fort Wayne_IN', 'Santa Ana_CA', 'Flint_MI', 'San Juan_PR', 'Fayetteville_NC', 'Jackson_MS', 'Santa Rosa_CA', 'Lansing_MI', 'Ann Arbor_MI', 'Henderson_NV', 'Huntsville_AL', 'Lexington_KY', 'Mobile_AL', 'Fort Collins_CO', 'Asheville_NC', 'Santa Clarita_CA', 'St. Paul_MN', 'Antioch_CA', 'Lakeland_FL', 'Trenton_NJ', 'Lincoln_NE', 'Springfield_MO', 'Plano_TX', 'Irvine_CA', 'Davenport_IA', 'Rockford_IL', 'Newark_NJ', 'South Bend_IN', 'Shreveport_LA', 'Round Lake Beach_IL', 'Savannah_GA', 'Myrtle Beach_SC', 'Chula Vista_CA', 'Eugene_OR', 'Canton_OH', 'Lubbock_TX', 'Reading_PA', 'Winter Haven_FL', 'Salem_OR', 'St. Petersburg_FL', 'Lafayette_LA', 'Laredo_TX', 'Jersey City_NJ', 'Concord_NC', 'Columbus_GA', 'Chandler_AZ', 'McKinney_TX', 'Scottsdale_AZ', 'Killeen_TX', 'Tallahassee_FL', 'Peoria_IL', 'Wilmington_NC', 'Montgomery_AL', 'Gilbert_AZ', 'Glendale_AZ', 'North Las Vegas_NV', 'Anchorage_AK', 'Chesapeake_VA', 'Barnstable Town_MA', 'Norfolk_VA', 'Fremont_CA', 'Kennewick_WA', 'Garland_TX', 'Irving_TX', 'Visalia_CA', 'Atlantic City_NJ', 'Nashua_NH', 'Paradise_NV', 'Hialeah_FL', 'York_PA', 'Arlington_VA', 'Evansville_IN', 'Avondale_AZ', 'Brownsville_TX', 'Gulfport_MS', 'Appleton_WI', 'Bremerton_WA', 'Hickory_NC', 'Tacoma_WA', 'San Bernardino_CA', 'College Station_TX', 'Kalamazoo_MI', 'Thousand Oaks_CA', 'Roanoke_VA', 'Fontana_CA', 'Moreno Valley_CA', 'North Port_FL', 'Fargo_ND', 'Green Bay_WI', 'Amarillo_TX', 'Portland_ME', 'Santa Barbara_CA', 'Gainesville_FL', 'Olympia_WA', 'Frisco_TX', 'Yonkers_NY', 'Norwich_CT', 'Spring Valley_NV', 'Glendale_CA', 'Huntington Beach_CA', 'Deltona_FL', 'Aurora_IL', 'Tempe_AZ', 'Overland Park_KS', 'Grand Prairie_TX', 'Sunrise Manor_NV', 'Waco_TX', 'Salinas_CA', 'Waterbury_CT', 'Clarksville_TN', 'Cedar Rapids_IA', 'Sioux Falls_SD', 'Huntington_WV', 'Ontario_CA', 'Hagerstown_MD', 'Erie_PA', 'Vancouver_WA', 'Nampa_ID', 'Spartanburg_SC', 'Gastonia_NC', 'Fort Lauderdale_FL', 'Lorain_OH', 'Murfreesboro_TN', 'High Point_NC', 'Newport Ne ...

# %%
len(missing_city)
# Out:
# 29488

# %%
list_diff = []
for item in our_list:
  if item not in missing_city:
    list_diff.append(item)

print(list_diff)
# Out:
# []

# %%
a = [x for x in dos['city_postal'].unique() if x not in df['city_postal'].unique()]
a
# Out:
# ['New York City_NY',
#  'Milford city (bala_CT',
#  'Milford_CT',
#  'Saint Charles_MO',
#  'Port Saint Lucie_FL',
#  'San Buenaventura (Ventura)_CA',
#  'Saint Petersburg_FL',
#  'Saint Peters_MO',
#  'Saint Paul_MN',
#  'Saint Joseph_MO',
#  'Saint George_UT',
#  'Saint Louis_MO',
#  'Saint Clair Shores_MI',
#  'Saint Cloud_MN',
#  'Winston Salem_NC']

# %%
# b = [x for x in df['city_postal'].unique() if x not in dos['city_postal'].unique
b = [x for x in df['city_postal'].unique() if x in dos['city_postal'].unique()]
b
# Out:
# ['Los Angeles_CA',
#  'Chicago_IL',
#  'Miami_FL',
#  'Dallas_TX',
#  'Philadelphia_PA',
#  'Houston_TX',
#  'Atlanta_GA',
#  'Washington_DC',
#  'Boston_MA',
#  'Phoenix_AZ',
#  'Seattle_WA',
#  'San Francisco_CA',
#  'Detroit_MI',
#  'San Diego_CA',
#  'Minneapolis_MN',
#  'Tampa_FL',
#  'Denver_CO',
#  'Riverside_CA',
#  'Baltimore_MD',
#  'Las Vegas_NV',
#  'Portland_OR',
#  'San Antonio_TX',
#  'Sacramento_CA',
#  'Orlando_FL',
#  'San Jose_CA',
#  'Cleveland_OH',
#  'Pittsburgh_PA',
#  'Austin_TX',
#  'Cincinnati_OH',
#  'Kansas City_MO',
#  'Indianapolis_IN',
#  'Columbus_OH',
#  'Charlotte_NC',
#  'Virginia Beach_VA',
#  'Milwaukee_WI',
#  'Providence_RI',
#  'Jacksonville_FL',
#  'Salt Lake City_UT',
#  'Nashville_TN',
#  'Richmond_VA',
#  'Memphis_TN',
#  'Raleigh_NC',
#  'New Orleans_LA',
#  'Oklahoma City_OK',
#  'Bridgeport_CT',
#  'Buffalo_NY',
#  'Fort Worth_TX',
#  'Hartford_CT',
#  'Tucson_AZ',
#  'Omaha_NE',
#  'El Paso_TX',
#  'Honolulu_HI',
#  'McAllen_TX',
#  'Albuquerque_NM',
#  'Birmingham_AL',
#  'Sarasota_FL',
#  'Dayton_OH',
#  'Rochester_NY',
#  'Fresno_CA',
#  'Allentown_PA',
#  'Tulsa_OK',
#  'Cape Coral_FL',
#  'Concord_CA',
#  'Colorado Springs_CO',
#  'Charleston_SC',
#  'Grand Rapids_MI',
#  'Mission Viejo_CA',
#  'Albany_NY',
#  'Knoxville_TN',
#  'Bakersfield_CA',
#  'Ogden_UT',
#  'Baton Rouge_LA',
#  'Akron_OH',
#  'New Haven_CT',
#  'Columbia_SC',
#  'Mesa_AZ',
#  'Palm Bay_FL',
#  'Wichita_KS',
#  'Toledo_OH',
#  'Des Moines_IA',
#  'Long Beach_CA',
#  'Denton_TX',
#  'Madison_WI',
#  'Reno_NV',
#  'Harrisburg_PA',
#  'Little Rock_AR',
#  'Oakland_CA',
#  'Durham_NC',
#  'Bonita Springs_FL',
#  'Indio_CA',
#  'Palm Coast_FL',
#  'Chattanooga_TN',
#  'Spokane_WA',
#  'Syracuse_NY',
#  'Arlington_TX',
#  'Stockton_CA',
#  'Boise_ID',
#  'Oxnard_CA',
#  'Scranton_PA',
#  'Modesto_CA',
#  'Kissimmee_FL',
#  'Aurora_CO',
#  'Anaheim_CA',
#  'Pensacola_FL',
#  'Victorville_CA',
#  'Lancaster_CA',
#  'Greensboro_NC',
#  'Corpus Christi_TX',
#  'Fort Wayne_IN',
#  'Santa Ana_CA',
#  'Flint_MI',
#  'Fayetteville_NC',
#  'Jackson_MS',
#  'Santa Rosa_CA',
#  'Lansing_MI',
#  'Ann Arbor_MI',
#  'Henderson_NV',
#  'Huntsville_AL',
#  'Mobile_AL',
#  'Asheville_NC',
#  'Santa Clarita_CA',
#  'Antioch_CA',
#  'Lakeland_FL',
#  'Trenton_NJ',
#  'Lincoln_NE',
#  'Springfield_MO',
#  'Plano_TX',
#  'Irvine_CA',
#  'Davenport_IA',
#  'Rockford_IL',
#  'Newark_NJ',
#  'South Bend_IN',
#  'Shreveport_LA',
#  'Savannah_GA',
#  'Chula Vista_CA',
#  'Canton_OH',
#  'Lubbock_TX',
#  'Reading_PA',
#  'Salem_OR',
#  'Lafayette_LA',
#  'Laredo_TX',
#  'Jersey City_NJ',
#  'Chandler_AZ',
#  'McKinney_TX',
#  'Scottsdale_AZ',
#  'Killeen_TX',
#  'Tallahassee_FL',
#  'Montgomery_AL',
#  'Glendale_AZ',
#  'North Las Vegas_NV',
#  'Chesapeake_VA',
#  'Norfolk_VA',
#  'Fremont_CA',
#  'Kennewick_WA',
#  'Garland_TX',
#  'Irving_TX',
#  'Visalia_CA',
#  'Nashua_NH',
#  'Hialeah_FL',
#  'Evansville_IN',
#  'Avondale_AZ',
#  'Brownsville_TX',
#  'Gulfport_MS',
#  'Appleton_WI',
#  'Tacoma_WA',
#  'San Bernardino_CA',
#  'College Station_TX',
#  'Kalamazoo_MI',
#  'Thousand Oaks_CA',
#  'Roanoke_VA',
#  'Fontana_CA',
#  'Moreno Valley_CA',
#  'North Port_FL',
#  'Green Bay_WI',
#  'Amarillo_TX',
#  'Santa Barbara_CA',
#  'Gainesville_FL',
#  'Olympia_WA',
#  'Frisco_TX',
#  'Huntington Beach_CA',
#  'Deltona_FL',
#  'Tempe_AZ',
#  'Overland Park_KS',
#  'Grand Prairie_TX',
#  'Waco_TX',
#  'Salinas_CA',
#  'Waterbury_CT',
#  'Clarksville_TN',
#  'Cedar Rapids_IA',
#  'Sioux Falls_SD',
#  'Ontario_CA',
#  'Erie_PA',
#  'Vancouver_WA',
#  'Nampa_ID',
#  'Gastonia_NC',
#  'Fort Lauderdale_FL',
#  'Lorain_OH',
#  'Murfreesboro_TN',
#  'High Point_NC',
#  'Newport News_VA',
#  'Rancho Cucamonga_CA',
#  'Hemet_CA',
#  'Santa Cruz_CA',
#  'Danbury_CT',
#  'Peoria_AZ',
#  'Oceanside_CA',
#  'Elk Grove_CA',
#  'Vallejo_CA',
#  'Medford_OR',
#  'Marysville_WA',
#  'Corona_CA',
#  'Ocala_FL',
#  'Manchester_NH',
#  'Champaign_IL',
#  'Alexandria_VA',
#  'Hayward_CA',
#  'Springfield_IL',
#  'Lakewood_CO',
#  'Frederick_MD',
#  'Lake Charles_LA',
#  'Tuscaloosa_AL',
#  'Warner Robins_GA',
#  'Palmdale_CA',
#  'Hollywood_FL',
#  'Midland_TX',
#  'Port Arthur_TX',
#  'Sunnyvale_CA',
#  'Pomona_CA',
#  'Escondido_CA',
#  'Pasadena_TX',
#  'New Bedford_MA',
#  'Fairfield_CA',
#  'Naperville_IL',
#  'Bellevue_WA',
#  'Elkhart_IN',
#  'Topeka_KS',
#  'Joliet_IL',
#  'Paterson_NJ',
#  'Merced_CA',
#  'Pueblo_CO',
#  'Tyler_TX',
#  'Torrance_CA',
#  'Surprise_AZ',
#  'Roseville_CA',
#  'Thornton_CO',
#  'Miramar_FL',
#  'Mesquite_TX',
#  'Santa Maria_CA',
#  'Olathe_KS',
#  'Carrollton_TX',
#  'Grand Junction_CO',
#  'Charleston_WV',
#  'Orange_CA',
#  'Fullerton_CA',
#  'Greeley_CO',
#  'Las Cruces_NM',
#  'Harlingen_TX',
#  'West Valley City_UT',
#  'Warren_MI',
#  'Coral Springs_FL',
#  'Round Rock_TX',
#  'Sterling Heights_MI',
#  'Kent_WA',
#  'Burlington_NC',
#  'Bellingham_WA',
#  'Santa Clara_CA',
#  'Racine_WI',
#  'Greenville_NC',
#  'Stamford_CT',
#  'Elizabeth_NJ',
#  'Johnson City_TN',
#  'Lynchburg_VA',
#  'Simi Valley_CA',
#  'Fort Smith_AR',
#  'Kenosha_WI',
#  'Boulder_CO',
#  'Berkeley_CA',
#  'Richardson_TX',
#  'Redding_CA',
#  'Arvada_CO',
#  'Billings_MT',
#  'Kingsport_TN',
#  'Duluth_MN',
#  'Rock Hill_SC',
#  'Gilroy_CA',
#  'Cambridge_MA',
#  'Sugar Land_TX',
#  'Texas City_TX',
#  'Iowa City_IA',
#  'Chico_CA',
#  'Dover_DE',
#  'Norman_OK',
#  'Clearwater_FL',
#  "Coeur d'Alene_ID",
#  'Bloomington_IN',
#  'El Monte_CA',
#  'Carlsbad_CA',
#  'North Charleston_SC',
#  'Temecula_CA',
#  'Clovis_CA',
#  'Meridian_ID',
#  'Westminster_CO',
#  'Costa Mesa_CA',
#  'Utica_NY',
#  'Pompano Beach_FL',
#  'West Palm Beach_FL',
#  'Waterloo_IA',
#  'Everett_WA',
#  'Santa Fe_NM',
#  'Downey_CA',
#  'Lowell_MA',
#  'Centennial_CO',
#  'Elgin_IL',
#  'Broken Arrow_OK',
#  'Miami Gardens_FL',
#  'Bend_OR',
#  'Jurupa Valley_CA',
#  'Sandy Springs_GA',
#  'Gresham_OR',
#  'Lewisville_TX',
#  'Hillsboro_OR',
#  'Inglewood_CA',
#  'League City_TX',
#  'Eau Claire_WI',
#  'Turlock_CA',
#  'Temple_TX',
#  'Sioux City_IA',
#  'Daly City_CA',
#  'Allen_TX',
#  'West Covina_CA',
#  'Sparks_NV',
#  'San Mateo_CA',
#  'Norwalk_CA',
#  'Rialto_CA',
#  'Manteca_CA',
#  'El Cajon_CA',
#  'Burbank_CA',
#  'Longmont_CO',
#  'Renton_WA',
#  'Vista_CA',
#  'Logan_UT',
#  'Vacaville_CA',
#  'Edinburg_TX',
#  'Carmel_IN',
#  'Spokane Valley_WA',
#  'San Angelo_TX',
#  'La Crosse_WI',
#  'Idaho Falls_ID',
#  'Longview_TX',
#  'Tracy_CA',
#  'Boca Raton_FL',
#  'Wichita Falls_TX',
#  'Rio Rancho_NM',
#  'South Fulton_GA',
#  'Beaverton_OR',
#  'Lawrence_KS',
#  'Bismarck_ND',
#  'Orem_UT',
#  'San Marcos_CA',
#  'Sandy_UT',
#  'Federal Way_WA',
#  'Hesperia_CA',
#  'Brockton_MA',
#  'Fishers_IN',
#  'Sunrise_FL',
#  'Bowling Green_KY',
#  'Roswell_GA',
#  'Menifee_CA',
#  'Plantation_FL',
#  'Quincy_MA',
#  'Portsmouth_VA',
#  'Chino_CA',
#  'Lynn_MA',
#  'Edmond_OK',
#  'Hanford_CA',
#  'Dearborn_MI',
#  'Livonia_MI',
#  'South Gate_CA',
#  'Vineland_NJ',
#  'Kirkland_WA',
#  'Missoula_MT',
#  'Rapid City_SD',
#  "Lee's Summit_MO",
#  'Terre Haute_IN',
#  'Suffolk_VA',
#  'Carson_CA',
#  'Conroe_TX',
#  'Livermore_CA',
#  'Lawton_OK',
#  'Santa Monica_CA',
#  'New Braunfels_TX',
#  'Fall River_MA',
#  'Miami Beach_FL',
#  'San Leandro_CA',
#  "O'Fallon_MO",
#  'Newton_MA',
#  'Muncie_IN',
#  'Citrus Heights_CA',
#  'Decatur_IL',
#  'Fort Myers_FL',
#  'Goodyear_AZ',
#  'Bryan_TX',
#  'Waukegan_IL',
#  'Hawthorne_CA',
#  'Anderson_IN',
#  'Redwood City_CA',
#  'Hoover_AL',
#  'Lake Forest_CA',
#  'Napa_CA',
#  'Whittier_CA',
#  'Clifton_NJ',
#  'Largo_FL',
#  'Johns Creek_GA',
#  'Newport Beach_CA',
#  'Mission_TX',
#  'Milpitas_CA',
#  'Troy_MI',
#  'Madera_CA',
#  'Joplin_MO',
#  'Chino Hills_CA',
#  'Alhambra_CA',
#  'Franklin_TN',
#  'Melbourne_FL',
#  'Mountain View_CA',
#  'Flagstaff_AZ',
#  'Buena Park_CA',
#  'Pleasanton_CA',
#  'Westland_MI',
#  'Auburn_WA',
#  'Cranston_RI',
#  'Somerville_MA',
#  'Folsom_CA',
#  'Springdale_AR',
#  'Deerfield Beach_FL',
#  'Warwick_RI',
#  'Farmington Hills_MI',
#  'Brooklyn Park_MN',
#  'Valdosta_GA',
#  'Plymouth_MN',
#  'Buckeye_AZ',
#  'Georgetown_TX',
#  'Cheyenne_WY',
#  'Cedar Park_TX',
#  'Kokomo_IN',
#  'Tustin_CA',
#  'Perris_CA',
#  'Pharr_TX',
#  'Loveland_CO',
#  'Boynton Beach_FL',
#  'New Rochelle_NY',
#  'Parma_OH',
#  'Layton_UT',
#  'Alameda_CA',
#  'Watsonville_CA',
#  'Porterville_CA',
#  'Baytown_TX',
#  'Upland_CA',
#  'Davis_CA',
#  'Camarillo_CA',
#  'South Jordan_UT',
#  'Battle Creek_MI',
#  'Bellflower_CA',
#  'Jonesboro_AR',
#  'San Ramon_CA',
#  'Bethlehem_PA',
#  'Oshkosh_WI',
#  'Hammond_IN',
#  'Missouri City_TX',
#  'Pasco_WA',
#  'Baldwin Park_CA',
#  'Rancho Cordova_CA',
#  'Conway_AR',
#  'Gary_IN',
#  'Lodi_CA',
#  'Rochester Hills_MI',
#  'Framingham_MA',
#  'Union City_CA',
#  'Owensboro_KY',
#  'Camden_NJ',
#  'Evanston_IL',
#  'Pocatello_ID',
#  'Woodbury_MN',
#  'Southfield_MI',
#  'Maple Grove_MN',
#  'Pittsburg_CA',
#  'New Britain_CT',
#  'Mansfield_TX',
#  'Dothan_AL',
#  'Harrisonburg_VA',
#  'Waukesha_WI',
#  'Pawtucket_RI',
#  'Redmond_WA',
#  'Lauderhill_FL',
#  'Redlands_CA',
#  'Weston_FL',
#  'Janesville_WI',
#  'North Richland Hills_TX',
#  'Broomfield_CO',
#  'Walnut Creek_CA',
#  'Lynwood_CA',
#  'Lehi_UT',
#  'Passaic_NJ',
#  'Homestead_FL',
#  'Delray Beach_FL',
#  'Lake Elsinore_CA',
#  'Daytona Beach_FL',
#  'Rocklin_CA',
#  'Rogers_AR',
#  'Bossier City_LA',
#  'Dubuque_IA',
#  'Rockville_MD',
#  'Victoria_TX',
#  'Gaithersburg_MD',
#  'Ames_IA',
#  'West Des Moines_IA',
#  'South San Francisco_CA',
#  'Casper_WY',
#  'Corvallis_OR',
#  'Ankeny_IA',
#  'Mount Vernon_NY',
#  'Rowlett_TX',
#  'Lakeville_MN',
#  'Alpharetta_GA',
#  'Petaluma_CA',
#  'Redondo Beach_CA',
#  'Tamarac_FL',
#  'Laguna Niguel_CA',
#  'Eagan_MN',
#  'Kenner_LA',
#  'North Little Rock_AR',
#  'Sammamish_WA',
#  'Shawnee_KS',
#  'Doral_FL',
#  'Blaine_MN',
#  'Tulare_CA',
#  'Pflugerville_TX',
#  'Palo Alto_CA',
#  'Schenectady_NY',
#  'Great Falls_MT',
#  'Bayonne_NJ',
#  'Eden Prairie_MN',
#  'Port Orange_FL',
#  'Dublin_CA',
#  'Grand Forks_ND',
#  'Noblesville_IN',
#  'San Clemente_CA',
#  'Brentwood_CA',
#  'East Orange_NJ',
#  'Eastvale_CA',
#  'Rocky Mount_NC',
#  'Haverhill_MA',
#  'Coon Rapids_MN',
#  'North Miami_FL',
#  'Encinitas_CA',
#  'Leander_TX',
#  'Waltham_MA',
#  'Council Bluffs_IA',
#  'Hamilton_OH',
#  'Moore_OK',
#  'Pico Rivera_CA',
#  'Casa Grande_AZ',
#  'Montebello_CA',
#  'Millcreek_UT',
#  'Sanford_FL',
#  'National City_CA',
#  'Burnsville_MN',
#  'Coconut Creek_FL',
#  'Taylor_MI',
#  'Novi_MI',
#  'Marietta_GA',
#  'La Habra_CA',
#  'Malden_MA',
#  'Commerce City_CO',
#  'Bristol_CT',
#  'West Allis_WI',
#  'Taylorsville_UT',
#  'Monterey Park_CA',
#  'Greenwood_IN',
#  'Bartlett_TN',
#  'Bradenton_FL',
#  'Pontiac_MI',
#  'Meriden_CT',
#  'Gardena_CA',
#  'Royal Oak_MI',
#  'Cupertino_CA',
#  'La Mesa_CA',
#  'Des Plaines_IL',
#  'Margate_FL',
#  'Carson City_NV',
#  'Bowie_MD',
#  'Caldwell_ID',
#  'San Rafael_CA',
#  'Richland_WA',
#  'Hendersonville_TN',
#  'White Plains_NY',
#  'Santee_CA',
#  'Jefferson City_MO',
#  'Arcadia_CA',
#  'Weymouth Town_MA',
#  'Palm Beach Gardens_FL',
#  'Huntington Park_CA',
#  'Taunton_MA',
#  'Midwest City_OK',
#  'Euless_TX',
#  'Manhattan_KS',
#  'Shoreline_WA',
#  'Lake Havasu City_AZ',
#  'Smyrna_GA',
#  'Blue Springs_MO',
#  'Southaven_MS',
#  'Diamond Bar_CA',
#  'New Brunswick_NJ',
#  'Lenexa_KS',
#  'Twin Falls_ID',
#  'Brookhaven_GA',
#  'Novato_CA',
#  'Tigard_OR',
#  'Highland_CA',
#  'Fountain Valley_CA',
#  'Dearborn Heights_MI',
#  'Grapevine_TX',
#  'Apple Valley_MN',
#  'Chicopee_MA',
#  'Cathedral City_CA',
#  'Delano_CA',
#  'Bentonville_AR',
#  'Stonecrest_GA',
#  'Kettering_OH',
#  'Colton_CA',
#  'West Haven_CT',
#  'Berwyn_IL',
#  'Minnetonka_MN',
#  'Rosemead_CA',
#  'Paramount_CA',
#  'Elyria_OH',
#  'Pinellas Park_FL',
#  'West Sacramento_CA',
#  'Apopka_FL',
#  'Grand Island_NE',
#  'Palm Desert_CA',
#  'Little Elm_TX',
#  'Revere_MA',
#  'Peabody_MA',
#  'DeSoto_TX',
#  'Helena_MT',
#  'Edina_MN',
#  'Wheaton_IL',
#  'Hoboken_NJ',
#  'Lacey_WA',
#  'Kentwood_MI',
#  'Glendora_CA',
#  'Burien_WA',
#  'Perth Amboy_NJ',
#  'Herriman_UT',
#  'Placentia_CA',
#  'West Lafayette_IN',
#  'Florissant_MO',
#  'Aliso Viejo_CA',
#  'Kannapolis_NC',
#  'Maricopa_AZ',
#  'Methuen Town_MA',
#  'Mishawaka_IN',
#  'Plainfield_NJ',
#  'Stillwater_OK',
#  'Galveston_TX',
#  'Concord_NH',
#  'Annapolis_MD',
#  'Frankfort_KY',
#  'Juneau_AK',
#  'Augusta_ME',
#  'Pierre_SD',
#  'Montpelier_VT']

# %%
len(df['city_postal'].unique())
# Out:
# 29319

# %%
len(dos['city_postal'].unique())
# Out:
# 687

# %%
a = [x for x in dos['city_postal'].unique() if x in df['city_postal'].unique()]
a
# Out:
# ['Alpharetta_GA',
#  'Allentown_PA',
#  'Allen_TX',
#  'Aliso Viejo_CA',
#  'Alhambra_CA',
#  'Alexandria_VA',
#  'Albuquerque_NM',
#  'Albany_NY',
#  'Alameda_CA',
#  'Akron_OH',
#  'Austin_TX',
#  'Aurora_CO',
#  'Augusta_ME',
#  'Auburn_WA',
#  'Atlanta_GA',
#  'Asheville_NC',
#  'Arvada_CO',
#  'Arlington_TX',
#  'Arcadia_CA',
#  'Apple Valley_MN',
#  'Appleton_WI',
#  'Apopka_FL',
#  'Antioch_CA',
#  'Ann Arbor_MI',
#  'Annapolis_MD',
#  'Ankeny_IA',
#  'Anderson_IN',
#  'Anaheim_CA',
#  'Ames_IA',
#  'Amarillo_TX',
#  'Boulder_CO',
#  'Boston_MA',
#  'Bossier City_LA',
#  'Bonita Springs_FL',
#  'Boise_ID',
#  'Boca Raton_FL',
#  'Blue Springs_MO',
#  'Bloomington_IN',
#  'Blaine_MN',
#  'Bismarck_ND',
#  'Birmingham_AL',
#  'Billings_MT',
#  'Bethlehem_PA',
#  'Berwyn_IL',
#  'Berkeley_CA',
#  'Bentonville_AR',
#  'Bend_OR',
#  'Bellingham_WA',
#  'Bellflower_CA',
#  'Bellevue_WA',
#  'Beaverton_OR',
#  'Baytown_TX',
#  'Bayonne_NJ',
#  'Battle Creek_MI',
#  'Baton Rouge_LA',
#  'Bartlett_TN',
#  'Baltimore_MD',
#  'Baldwin Park_CA',
#  'Bakersfield_CA',
#  'Avondale_AZ',
#  'Chino Hills_CA',
#  'Chino_CA',
#  'Chicopee_MA',
#  'Chico_CA',
#  'Chicago_IL',
#  'Chesapeake_VA',
#  'Cheyenne_WY',
#  'Chattanooga_TN',
#  'Charlotte_NC',
#  'Charleston_WV',
#  'Charleston_SC',
#  'Chandler_AZ',
#  'Champaign_IL',
#  'Centennial_CO',
#  'Cedar Rapids_IA',
#  'Cedar Park_TX',
#  'Cathedral City_CA',
#  'Casa Grande_AZ',
#  'Casper_WY',
#  'Carson City_NV',
#  'Carson_CA',
#  'Carrollton_TX',
#  'Carmel_IN',
#  'Carlsbad_CA',
#  'Canton_OH',
#  'Cape Coral_FL',
#  'Camden_NJ',
#  'Cambridge_MA',
#  'Camarillo_CA',
#  'Caldwell_ID',
#  'Burnsville_MN',
#  'Burlington_NC',
#  'Burien_WA',
#  'Burbank_CA',
#  'Buffalo_NY',
#  'Buena Park_CA',
#  'Buckeye_AZ',
#  'Bryan_TX',
#  'Brownsville_TX',
#  'Broomfield_CO',
#  'Brooklyn Park_MN',
#  'Brookhaven_GA',
#  'Broken Arrow_OK',
#  'Brockton_MA',
#  'Bristol_CT',
#  'Bridgeport_CT',
#  'Brentwood_CA',
#  'Bradenton_FL',
#  'Boynton Beach_FL',
#  'Bowling Green_KY',
#  'Bowie_MD',
#  'Flint_MI',
#  'Flagstaff_AZ',
#  'Fishers_IN',
#  'Federal Way_WA',
#  'Fayetteville_NC',
#  'Farmington Hills_MI',
#  'Fall River_MA',
#  'Fairfield_CA',
#  'Everett_WA',
#  'Evansville_IN',
#  'Evanston_IL',
#  'Euless_TX',
#  'Escondido_CA',
#  'Erie_PA',
#  'Elyria_OH',
#  'El Paso_TX',
#  'Encinitas_CA',
#  'El Monte_CA',
#  'Elk Grove_CA',
#  'Elkhart_IN',
#  'Elizabeth_NJ',
#  'Elgin_IL',
#  'El Cajon_CA',
#  'Edmond_OK',
#  'Edinburg_TX',
#  'Edina_MN',
#  'Eden Prairie_MN',
#  'Eau Claire_WI',
#  'Eastvale_CA',
#  'East Orange_NJ',
#  'Eagan_MN',
#  'Durham_NC',
#  'Duluth_MN',
#  'Dubuque_IA',
#  'Dublin_CA',
#  'Downey_CA',
#  'Dover_DE',
#  'Dothan_AL',
#  'Doral_FL',
#  'Diamond Bar_CA',
#  'Detroit_MI',
#  'Des Plaines_IL',
#  'DeSoto_TX',
#  'Des Moines_IA',
#  'Denver_CO',
#  'Denton_TX',
#  'Deltona_FL',
#  'Delray Beach_FL',
#  'Delano_CA',
#  'Deerfield Beach_FL',
#  'Decatur_IL',
#  'Dearborn Heights_MI',
#  'Daytona Beach_FL',
#  'Dearborn_MI',
#  'Davis_CA',
#  'Davenport_IA',
#  'Dayton_OH',
#  'Danbury_CT',
#  'Daly City_CA',
#  'Dallas_TX',
#  'Cupertino_CA',
#  'Cranston_RI',
#  'Council Bluffs_IA',
#  'Costa Mesa_CA',
#  'Corvallis_OR',
#  'Corpus Christi_TX',
#  'Corona_CA',
#  'Coral Springs_FL',
#  'Coon Rapids_MN',
#  'Conway_AR',
#  'Conroe_TX',
#  'Concord_NH',
#  'Concord_CA',
#  'Commerce City_CO',
#  'Columbus_OH',
#  'Columbia_SC',
#  'Colton_CA',
#  'Colorado Springs_CO',
#  'College Station_TX',
#  "Coeur d'Alene_ID",
#  'Coconut Creek_FL',
#  'Clovis_CA',
#  'Clifton_NJ',
#  'Cleveland_OH',
#  'Clearwater_FL',
#  'Clarksville_TN',
#  'Citrus Heights_CA',
#  'Cincinnati_OH',
#  'Chula Vista_CA',
#  'Hartford_CT',
#  'Harrisonburg_VA',
#  'Harrisburg_PA',
#  'Harlingen_TX',
#  'Hanford_CA',
#  'Hammond_IN',
#  'Hamilton_OH',
#  'Gulfport_MS',
#  'Gresham_OR',
#  'Greenwood_IN',
#  'Greenville_NC',
#  'Greensboro_NC',
#  'Green Bay_WI',
#  'Greeley_CO',
#  'Great Falls_MT',
#  'Grapevine_TX',
#  'Grand Rapids_MI',
#  'Grand Prairie_TX',
#  'Grand Junction_CO',
#  'Grand Island_NE',
#  'Grand Forks_ND',
#  'Goodyear_AZ',
#  'Glendora_CA',
#  'Glendale_AZ',
#  'Gilroy_CA',
#  'Georgetown_TX',
#  'Gastonia_NC',
#  'Gary_IN',
#  'Garland_TX',
#  'Gardena_CA',
#  'Galveston_TX',
#  'Gaithersburg_MD',
#  'Gainesville_FL',
#  'Fullerton_CA',
#  'Frisco_TX',
#  'Fresno_CA',
#  'Fremont_CA',
#  'Frederick_MD',
#  'Franklin_TN',
#  'Frankfort_KY',
#  'Framingham_MA',
#  'Fountain Valley_CA',
#  'Fort Worth_TX',
#  'Fort Wayne_IN',
#  'Fort Smith_AR',
#  'Fort Myers_FL',
#  'Fort Lauderdale_FL',
#  'Folsom_CA',
#  'Fontana_CA',
#  'Florissant_MO',
#  'Lubbock_TX',
#  'Lowell_MA',
#  'Loveland_CO',
#  'Los Angeles_CA',
#  'Lorain_OH',
#  'Longview_TX',
#  'Long Beach_CA',
#  'Longmont_CO',
#  'Logan_UT',
#  'Lodi_CA',
#  'Livonia_MI',
#  'Livermore_CA',
#  'Little Rock_AR',
#  'Little Elm_TX',
#  'Lincoln_NE',
#  'Lewisville_TX',
#  'Lenexa_KS',
#  'Lehi_UT',
#  "Lee's Summit_MO",
#  'Leander_TX',
#  'League City_TX',
#  'Layton_UT',
#  'Lawton_OK',
#  'Lawrence_KS',
#  'Lauderhill_FL',
#  'Las Vegas_NV',
#  'Las Cruces_NM',
#  'Largo_FL',
#  'Laredo_TX',
#  'Lansing_MI',
#  'La Mesa_CA',
#  'Lancaster_CA',
#  'Lakewood_CO',
#  'Lakeville_MN',
#  'Lake Havasu City_AZ',
#  'Lakeland_FL',
#  'Lake Forest_CA',
#  'Lake Charles_LA',
#  'Lake Elsinore_CA',
#  'La Habra_CA',
#  'Laguna Niguel_CA',
#  'Lafayette_LA',
#  'La Crosse_WI',
#  'Lacey_WA',
#  'Kokomo_IN',
#  'Knoxville_TN',
#  'Kirkland_WA',
#  'Kissimmee_FL',
#  'Kingsport_TN',
#  'Killeen_TX',
#  'Kettering_OH',
#  'Kentwood_MI',
#  'Kent_WA',
#  'Kenosha_WI',
#  'Kennewick_WA',
#  'Kenner_LA',
#  'Kansas City_MO',
#  'Kannapolis_NC',
#  'Kalamazoo_MI',
#  'Jurupa Valley_CA',
#  'Juneau_AK',
#  'Joplin_MO',
#  'Jonesboro_AR',
#  'Joliet_IL',
#  'Johnson City_TN',
#  'Johns Creek_GA',
#  'Jersey City_NJ',
#  'Jefferson City_MO',
#  'Janesville_WI',
#  'Jacksonville_FL',
#  'Jackson_MS',
#  'Irving_TX',
#  'Irvine_CA',
#  'Iowa City_IA',
#  'Inglewood_CA',
#  'Indio_CA',
#  'Indianapolis_IN',
#  'Idaho Falls_ID',
#  'Huntsville_AL',
#  'Huntington Park_CA',
#  'Huntington Beach_CA',
#  'Houston_TX',
#  'Hoover_AL',
#  'Honolulu_HI',
#  'Homestead_FL',
#  'Hollywood_FL',
#  'Hoboken_NJ',
#  'High Point_NC',
#  'Hillsboro_OR',
#  'Highland_CA',
#  'Hialeah_FL',
#  'Hesperia_CA',
#  'Herriman_UT',
#  'Hendersonville_TN',
#  'Henderson_NV',
#  'Hayward_CA',
#  'Hemet_CA',
#  'Helena_MT',
#  'Hawthorne_CA',
#  'Haverhill_MA',
#  'Oceanside_CA',
#  'Ocala_FL',
#  'Oakland_CA',
#  'Novi_MI',
#  'Novato_CA',
#  'Norwalk_CA',
#  'North Richland Hills_TX',
#  'North Port_FL',
#  'North Little Rock_AR',
#  'North Miami_FL',
#  'North Las Vegas_NV',
#  'North Charleston_SC',
#  'Norman_OK',
#  'Norfolk_VA',
#  'Noblesville_IN',
#  'Newton_MA',
#  'New Rochelle_NY',
#  'Newport News_VA',
#  'Newport Beach_CA',
#  'New Orleans_LA',
#  'New Haven_CT',
#  'New Brunswick_NJ',
#  'New Britain_CT',
#  'New Braunfels_TX',
#  'New Bedford_MA',
#  'Newark_NJ',
#  'National City_CA',
#  'Nashville_TN',
#  'Nashua_NH',
#  'Naperville_IL',
#  'Napa_CA',
#  'Nampa_ID',
#  'Murfreesboro_TN',
#  'Muncie_IN',
#  'Mount Vernon_NY',
#  'Mountain View_CA',
#  'Moreno Valley_CA',
#  'Moore_OK',
#  'Montpelier_VT',
#  'Montgomery_AL',
#  'Monterey Park_CA',
#  'Montebello_CA',
#  'Modesto_CA',
#  'Mobile_AL',
#  'Missouri City_TX',
#  'Missoula_MT',
#  'Mission Viejo_CA',
#  'Mission_TX',
#  'Mishawaka_IN',
#  'Miramar_FL',
#  'Minnetonka_MN',
#  'Minneapolis_MN',
#  'Milwaukee_WI',
#  'Milpitas_CA',
#  'Millcreek_UT',
#  'Midland_TX',
#  'Midwest City_OK',
#  'Miami Gardens_FL',
#  'Miami Beach_FL',
#  'Miami_FL',
#  'Methuen Town_MA',
#  'Mesquite_TX',
#  'Mesa_AZ',
#  'Meridian_ID',
#  'Meriden_CT',
#  'Merced_CA',
#  'Menifee_CA',
#  'Memphis_TN',
#  'Melbourne_FL',
#  'Medford_OR',
#  'McAllen_TX',
#  'McKinney_TX',
#  'Maricopa_AZ',
#  'Marietta_GA',
#  'Marysville_WA',
#  'Margate_FL',
#  'Maple Grove_MN',
#  'Manteca_CA',
#  'Mansfield_TX',
#  'Manhattan_KS',
#  'Manchester_NH',
#  'Malden_MA',
#  'Madison_WI',
#  'Madera_CA',
#  'Lynwood_CA',
#  'Lynn_MA',
#  'Lynchburg_VA',
#  'Sacramento_CA',
#  'Royal Oak_MI',
#  'Rowlett_TX',
#  'Round Rock_TX',
#  'Roswell_GA',
#  'Roseville_CA',
#  'Rosemead_CA',
#  'Rogers_AR',
#  'Rocky Mount_NC',
#  'Rockville_MD',
#  'Rocklin_CA',
#  'Rock Hill_SC',
#  'Rockford_IL',
#  'Rochester Hills_MI',
#  'Rochester_NY',
#  'Roanoke_VA',
#  'Riverside_CA',
#  'Rio Rancho_NM',
#  'Richmond_VA',
#  'Richland_WA',
#  'Richardson_TX',
#  'Rialto_CA',
#  'Revere_MA',
#  'Renton_WA',
#  'Reno_NV',
#  'Redwood City_CA',
#  'Redondo Beach_CA',
#  'Redmond_WA',
#  'Redlands_CA',
#  'Redding_CA',
#  'Reading_PA',
#  'Rapid City_SD',
#  'Rancho Cucamonga_CA',
#  'Rancho Cordova_CA',
#  'Quincy_MA',
#  'Raleigh_NC',
#  'Racine_WI',
#  'Pueblo_CO',
#  'Providence_RI',
#  'Portsmouth_VA',
#  'Port Orange_FL',
#  'Portland_OR',
#  'Porterville_CA',
#  'Port Arthur_TX',
#  'Pontiac_MI',
#  'Pompano Beach_FL',
#  'Pomona_CA',
#  'Pocatello_ID',
#  'Plymouth_MN',
#  'Pleasanton_CA',
#  'Plantation_FL',
#  'Plano_TX',
#  'Plainfield_NJ',
#  'Placentia_CA',
#  'Pittsburgh_PA',
#  'Pittsburg_CA',
#  'Pinellas Park_FL',
#  'Pierre_SD',
#  'Petaluma_CA',
#  'Pico Rivera_CA',
#  'Phoenix_AZ',
#  'Philadelphia_PA',
#  'Pharr_TX',
#  'Pflugerville_TX',
#  'Perth Amboy_NJ',
#  'Perris_CA',
#  'Peoria_AZ',
#  'Pensacola_FL',
#  'Peabody_MA',
#  'Pawtucket_RI',
#  'Passaic_NJ',
#  'Pasco_WA',
#  'Paterson_NJ',
#  'Pasadena_TX',
#  'Parma_OH',
#  'Paramount_CA',
#  'Palo Alto_CA',
#  'Palm Desert_CA',
#  'Palmdale_CA',
#  'Palm Coast_FL',
#  'Palm Beach Gardens_FL',
#  'Palm Bay_FL',
#  'Oxnard_CA',
#  'Owensboro_KY',
#  'Overland Park_KS',
#  'Oshkosh_WI',
#  'Orlando_FL',
#  'Orem_UT',
#  'Orange_CA',
#  'Ontario_CA',
#  'Omaha_NE',
#  'Olympia_WA',
#  'Olathe_KS',
#  'Oklahoma City_OK',
#  'Ogden_UT',
#  "O'Fallon_MO",
#  'Southaven_MS',
#  'Somerville_MA',
#  'Smyrna_GA',
#  'Sioux Falls_SD',
#  'Sioux City_IA',
#  'Simi Valley_CA',
#  'Shreveport_LA',
#  'Shoreline_WA',
#  'Seattle_WA',
#  'Shawnee_KS',
#  'Scranton_PA',
#  'Scottsdale_AZ',
#  'Schenectady_NY',
#  'Savannah_GA',
#  'Sarasota_FL',
#  'Santee_CA',
#  'Santa Rosa_CA',
#  'Santa Monica_CA',
#  'Santa Maria_CA',
#  'Santa Fe_NM',
#  'Santa Cruz_CA',
#  'Santa Clarita_CA',
#  'Santa Clara_CA',
#  'Santa Barbara_CA',
#  'Santa Ana_CA',
#  'San Ramon_CA',
#  'San Rafael_CA',
#  'San Mateo_CA',
#  'San Marcos_CA',
#  'San Leandro_CA',
#  'San Jose_CA',
#  'San Francisco_CA',
#  'Sanford_FL',
#  'Sandy Springs_GA',
#  'Sandy_UT',
#  'San Diego_CA',
#  'San Clemente_CA',
#  'San Bernardino_CA',
#  'San Antonio_TX',
#  'San Angelo_TX',
#  'Sammamish_WA',
#  'Salt Lake City_UT',
#  'Salinas_CA',
#  'Salem_OR',
#  'Woodbury_MN',
#  'Wichita_KS',
#  'Wichita Falls_TX',
#  'White Plains_NY',
#  'Whittier_CA',
#  'Wheaton_IL',
#  'Weymouth Town_MA',
#  'West Valley City_UT',
#  'West Sacramento_CA',
#  'West Palm Beach_FL',
#  'Weston_FL',
#  'Westland_MI',
#  'Westminster_CO',
#  'West Lafayette_IN',
#  'West Haven_CT',
#  'West Des Moines_IA',
#  'West Covina_CA',
#  'West Allis_WI',
#  'Waukesha_WI',
#  'Waukegan_IL',
#  'Watsonville_CA',
#  'Waterloo_IA',
#  'Waterbury_CT',
#  'Washington_DC',
#  'Warwick_RI',
#  'Warren_MI',
#  'Warner Robins_GA',
#  'Waltham_MA',
#  'Walnut Creek_CA',
#  'Waco_TX',
#  'Vista_CA',
#  'Visalia_CA',
#  'Vineland_NJ',
#  'Virginia Beach_VA',
#  'Victorville_CA',
#  'Victoria_TX',
#  'Vancouver_WA',
#  'Vallejo_CA',
#  'Valdosta_GA',
#  'Vacaville_CA',
#  'Utica_NY',
#  'Upland_CA',
#  'Union City_CA',
#  'Tyler_TX',
#  'Twin Falls_ID',
#  'Tustin_CA',
#  'Tuscaloosa_AL',
#  'Turlock_CA',
#  'Tulsa_OK',
#  'Tulare_CA',
#  'Tucson_AZ',
#  'Troy_MI',
#  'Trenton_NJ',
#  'Tracy_CA',
#  'Torrance_CA',
#  'Topeka_KS',
#  'Toledo_OH',
#  'Tigard_OR',
#  'Thousand Oaks_CA',
#  'Thornton_CO',
#  'Texas City_TX',
#  'Terre Haute_IN',
#  'Temple_TX',
#  'Tempe_AZ',
#  'Temecula_CA',
#  'Taylorsville_UT',
#  'Taylor_MI',
#  'Taunton_MA',
#  'Tampa_FL',
#  'Tamarac_FL',
#  'Tallahassee_FL',
#  'Tacoma_WA',
#  'Syracuse_NY',
#  'Surprise_AZ',
#  'Sunrise_FL',
#  'Sunnyvale_CA',
#  'Sugar Land_TX',
#  'Suffolk_VA',
#  'Stonecrest_GA',
#  'Stockton_CA',
#  'Stillwater_OK',
#  'Sterling Heights_MI',
#  'Stamford_CT',
#  'Springfield_MO',
#  'Springfield_IL',
#  'Springdale_AR',
#  'Spokane Valley_WA',
#  'Spokane_WA',
#  'Sparks_NV',
#  'South San Francisco_CA',
#  'South Jordan_UT',
#  'South Gate_CA',
#  'South Fulton_GA',
#  'Southfield_MI',
#  'South Bend_IN']

# %%
cd = df[df['city_postal']== 'St. Joseph_MO']
cd
# Out:
#            city  city_ascii  ...          id    city_postal
# 596  St. Joseph  St. Joseph  ...  1840009549  St. Joseph_MO
#
# [1 rows x 18 columns]

# %% [markdown]
# # **Cleaned, made sure the city_postals were written in the correct format**

# %%
dos.loc[dos['city_postal']== 'Saint Clair Shores_MI', 'city_postal'] = 'St. Clair Shores_MI' 
dos.loc[dos['city_postal']== 'Saint Paul_MN', 'city_postal'] = 'St. Paul_MN'
dos.loc[dos['city_postal']== 'Saint Charles_MO', 'city_postal'] = 'St. Charles_MO'
dos.loc[dos['city_postal']== 'Port Saint Lucie_FL', 'city_postal'] = 'Port St. Lucie_FL'
dos.loc[dos['city_postal']== 'Milford_CT', 'city_postal'] = 'New Milford_CT'
dos.loc[dos['city_postal']== 'Saint Cloud_MN', 'city_postal'] = 'St. Cloud_MN'
dos.loc[dos['city_postal']== 'Saint Louis_MO', 'city_postal'] = 'St. Louis_MO'
dos.loc[dos['city_postal']== 'Saint George_UT', 'city_postal'] = 'St. George_UT'
dos.loc[dos['city_postal']== 'Winston Salem_NC', 'city_postal'] = 'Winston-Salem_NC'
dos.loc[dos['city_postal']== 'Saint Petersburg_FL', 'city_postal'] = 'St. Petersburg_FL'
dos.loc[dos['city_postal']== 'New York City_NY', 'city_postal'] = 'New York_NY'
dos.loc[dos['city_postal']== 'Saint Peters_MO', 'city_postal'] = 'St. Peters_MO'
dos.loc[dos['city_postal']== 'San Buenaventura (Ventura)_CA', 'city_postal'] = 'San Buenaventura_CA'
dos.loc[dos['city_postal']== 'Saint Joseph_MO', 'city_postal'] = 'St. Joseph_MO'

# %%
a = dos[dos['city_postal']== 'San Buenaventura_CA']
a
# Out:
#                                City Postal  ...   date_time          city_postal
# 1017664  San Buenaventura (Ventura)     CA  ...  2015-01-01  San Buenaventura_CA
# 1017665  San Buenaventura (Ventura)     CA  ...  2015-01-02  San Buenaventura_CA
# 1017666  San Buenaventura (Ventura)     CA  ...  2015-01-03  San Buenaventura_CA
# 1017667  San Buenaventura (Ventura)     CA  ...  2015-01-04  San Buenaventura_CA
# 1017668  San Buenaventura (Ventura)     CA  ...  2015-01-05  San Buenaventura_CA
# ...                             ...    ...  ...         ...                  ...
# 1019467  San Buenaventura (Ventura)     CA  ...  2019-12-27  San Buenaventura_CA
# 1019468  San Buenaventura (Ventura)     CA  ...  2019-12-28  San Buenaventura_CA
# 1019469  San Buenaventura (Ventura)     CA  ...  2019-12-29  San Buenaventura_CA
# 1019470  San Buenaventura (Ventura)     CA  ...  2019-12-30  San Buenaventura_CA
# 1019471  San Buenaventura (Ventura)     CA  ...  2019-12-31  San Buenaventura_CA
#
# [1808 rows x 26 columns]

# %%
a = dos[dos['city_postal']== dos['city_postal']]
a
# Out:
#                City Postal      City_State  ...  day   date_time    city_postal
# 0        Alpharetta     GA  Alpharetta, GA  ...    1  2015-01-01  Alpharetta_GA
# 1        Alpharetta     GA  Alpharetta, GA  ...    2  2015-01-02  Alpharetta_GA
# 2        Alpharetta     GA  Alpharetta, GA  ...    3  2015-01-03  Alpharetta_GA
# 3        Alpharetta     GA  Alpharetta, GA  ...    4  2015-01-04  Alpharetta_GA
# 4        Alpharetta     GA  Alpharetta, GA  ...    5  2015-01-05  Alpharetta_GA
# ...             ...    ...             ...  ...  ...         ...            ...
# 1215197  South Bend     IN  South Bend, IN  ...   26  2019-12-26  South Bend_IN
# 1215198  South Bend     IN  South Bend, IN  ...   28  2019-12-28  South Bend_IN
# 1215199  South Bend     IN  South Bend, IN  ...   29  2019-12-29  South Bend_IN
# 1215200  South Bend     IN  South Bend, IN  ...   30  2019-12-30  South Bend_IN
# 1215201  South Bend     IN  South Bend, IN  ...   31  2019-12-31  South Bend_IN
#
# [1215202 rows x 26 columns]

# %% [markdown]
# # **Merged Datasets together on city_postal since they match up and all the cities from the weather data are in the geo data & vice versa**

# %%
both = pd.merge(df, dos, how='inner', on='city_postal')
both
# Out:
#                 city   city_ascii state_id  ... month  day   date_time
# 0           New York     New York       NY  ...     1    1  2015-01-01
# 1           New York     New York       NY  ...     1    2  2015-01-02
# 2           New York     New York       NY  ...     1    3  2015-01-03
# 3           New York     New York       NY  ...     1    4  2015-01-04
# 4           New York     New York       NY  ...     1    5  2015-01-05
# ...              ...          ...      ...  ...   ...  ...         ...
# 1220736  New Milford  New Milford       CT  ...    12   27  2019-12-27
# 1220737  New Milford  New Milford       CT  ...    12   28  2019-12-28
# 1220738  New Milford  New Milford       CT  ...    12   29  2019-12-29
# 1220739  New Milford  New Milford       CT  ...    12   30  2019-12-30
# 1220740  New Milford  New Milford       CT  ...    12   31  2019-12-31
#
# [1220741 rows x 43 columns]

# %%
drop_these = ['city_ascii', 'county_fips', 'density', 'source', 'incorporated', 'ranking', 'zips', 'id']

# %%
both.drop(columns=drop_these)
# Out:
#                 city state_id   state_name  ... month  day   date_time
# 0           New York       NY     New York  ...     1    1  2015-01-01
# 1           New York       NY     New York  ...     1    2  2015-01-02
# 2           New York       NY     New York  ...     1    3  2015-01-03
# 3           New York       NY     New York  ...     1    4  2015-01-04
# 4           New York       NY     New York  ...     1    5  2015-01-05
# ...              ...      ...          ...  ...   ...  ...         ...
# 1220736  New Milford       CT  Connecticut  ...    12   27  2019-12-27
# 1220737  New Milford       CT  Connecticut  ...    12   28  2019-12-28
# 1220738  New Milford       CT  Connecticut  ...    12   29  2019-12-29
# 1220739  New Milford       CT  Connecticut  ...    12   30  2019-12-30
# 1220740  New Milford       CT  Connecticut  ...    12   31  2019-12-31
#
# [1220741 rows x 35 columns]

# %%
both.drop(columns=['city_ascii', 'county_fips', 'density', 'source', 'incorporated', 'ranking', 'zips'])
# Out:
#                 city state_id   state_name  ... month  day   date_time
# 0           New York       NY     New York  ...     1    1  2015-01-01
# 1           New York       NY     New York  ...     1    2  2015-01-02
# 2           New York       NY     New York  ...     1    3  2015-01-03
# 3           New York       NY     New York  ...     1    4  2015-01-04
# 4           New York       NY     New York  ...     1    5  2015-01-05
# ...              ...      ...          ...  ...   ...  ...         ...
# 1220736  New Milford       CT  Connecticut  ...    12   27  2019-12-27
# 1220737  New Milford       CT  Connecticut  ...    12   28  2019-12-28
# 1220738  New Milford       CT  Connecticut  ...    12   29  2019-12-29
# 1220739  New Milford       CT  Connecticut  ...    12   30  2019-12-30
# 1220740  New Milford       CT  Connecticut  ...    12   31  2019-12-31
#
# [1220741 rows x 36 columns]

# %%
a = both[both['city_postal']== 'San Buenaventura_CA']
a
# Out:
#                     city        city_ascii state_id  ... month  day   date_time
# 584698  San Buenaventura  San Buenaventura       CA  ...     1    1  2015-01-01
# 584699  San Buenaventura  San Buenaventura       CA  ...     1    2  2015-01-02
# 584700  San Buenaventura  San Buenaventura       CA  ...     1    3  2015-01-03
# 584701  San Buenaventura  San Buenaventura       CA  ...     1    4  2015-01-04
# 584702  San Buenaventura  San Buenaventura       CA  ...     1    5  2015-01-05
# ...                  ...               ...      ...  ...   ...  ...         ...
# 586501  San Buenaventura  San Buenaventura       CA  ...    12   27  2019-12-27
# 586502  San Buenaventura  San Buenaventura       CA  ...    12   28  2019-12-28
# 586503  San Buenaventura  San Buenaventura       CA  ...    12   29  2019-12-29
# 586504  San Buenaventura  San Buenaventura       CA  ...    12   30  2019-12-30
# 586505  San Buenaventura  San Buenaventura       CA  ...    12   31  2019-12-31
#
# [1808 rows x 43 columns]

# %%
both.shape
# Out:
# (1220741, 43)

# %%
both.to_csv(r'C:\Users\kingf\Desktop\both.csv', index=None, header=True)

# %%
both.to_csv('both.csv')
# !cp both.csv "drive/My Drive/"

# %%
df['city_postal'].shape
# Out:
# (29488,)

# %%
both['city_postal'].value_counts()
# Out:
# Burbank_CA           3644
# Plantation_FL        3644
# Mountain View_CA     3644
# Mesquite_TX          3604
# Honolulu_HI          1823
#                      ...
# Spokane_WA           1675
# Coeur d'Alene_ID     1665
# Carson City_NV       1664
# Spokane Valley_WA    1659
# Juneau_AK            1619
# Name: city_postal, Length: 686, dtype: int64

# %%
# both[both['county_name']== 'stearns'].head()

# %%
# both.head()

# %%
# def grab_lab(x):
#   for i in both['city_postal']:
#     if x == i:
#       both['lat'] = df['lat']
#     return x

# %%
# df['city_postal'].apply(grab_lab)

# %%
dos.dtypes
# Out:
# City               object
# Postal             object
# City_State         object
# MaxTempF          float64
# FeelsLikeF        float64
# MinTempF          float64
# MaxTempC            int64
# FeelsLikeC          int64
# MinTempC            int64
# Precip_mm         float64
# TotalSnow_cm      float64
# UVindex             int64
# DewPointC           int64
# HeatIndexC          int64
# WindChillC          int64
# WindGust_kmph       int64
# CloudCover          int64
# Humidity            int64
# Pressure            int64
# Visibility          int64
# WindSpeed_kmph      int64
# year                int64
# month               int64
# day                 int64
# date_time          object
# city_postal        object
# dtype: object

# %%
len(missing_city)
# Out:
# 29488

# %%
dictionary = {}
for i in df['city']:
  if i not in dictionary:
    dictionary[i] = 0
    dictionary[i] += 1
  else:
    dictionary[i] += 1
  

dictionary
# Out:
# {'New York': 1,
#  'Los Angeles': 2,
#  'Chicago': 1,
#  'Miami': 5,
#  'Dallas': 7,
#  'Philadelphia': 4,
#  'Houston': 8,
#  'Atlanta': 9,
#  'Washington': 18,
#  'Boston': 6,
#  'Phoenix': 4,
#  'Seattle': 1,
#  'San Francisco': 1,
#  'Detroit': 6,
#  'San Diego': 2,
#  'Minneapolis': 2,
#  'Tampa': 2,
#  'Denver': 6,
#  'Brooklyn': 8,
#  'Queens': 1,
#  'Riverside': 18,
#  'Baltimore': 2,
#  'Las Vegas': 2,
#  'Portland': 12,
#  'San Antonio': 6,
#  'St. Louis': 3,
#  'Sacramento': 3,
#  'Orlando': 2,
#  'San Jose': 5,
#  'Cleveland': 17,
#  'Pittsburgh': 1,
#  'Austin': 6,
#  'Cincinnati': 2,
#  'Kansas City': 2,
#  'Manhattan': 4,
#  'Indianapolis': 1,
#  'Columbus': 16,
#  'Charlotte': 5,
#  'Virginia Beach': 1,
#  'Bronx': 1,
#  'Milwaukee': 1,
#  'Providence': 4,
#  'Jacksonville': 14,
#  'Salt Lake City': 1,
#  'Nashville': 9,
#  'Richmond': 15,
#  'Memphis': 8,
#  'Raleigh': 5,
#  'New Orleans': 1,
#  'Louisville': 10,
#  'Oklahoma City': 1,
#  'Bridgeport': 13,
#  'Buffalo': 16,
#  'Fort Worth': 1,
#  'Hartford': 11,
#  'Tucson': 1,
#  'Omaha': 4,
#  'El Paso': 2,
#  'Honolulu': 1,
#  'McAllen': 1,
#  'Albuquerque': 1,
#  'Birmingham': 5,
#  'Sarasota': 1,
#  'Dayton': 18,
#  'Rochester': 14,
#  'Fresno': 3,
#  'Allentown': 4,
#  'Tulsa': 1,
#  'Cape Coral': 1,
#  'Concord': 13,
#  'Colorado Springs': 1,
#  'Charleston': 8,
#  'Springfield': 20,
#  'Grand Rapids': 3,
#  'Mission Viejo': 1,
#  'Albany': 16,
#  'Knoxville': 6,
#  'Bakersfield': 2,
#  'Ogden': 6,
#  'Baton Rouge': 1,
#  'Akron': 8,
#  'New Haven': 10,
#  'Columbia': 15,
#  'Mesa': 3,
#  'Palm Bay': 1,
#  'Provo': 1,
#  'Worcester': 3,
#  'Murrieta': 1,
#  'Greenville': 23,
#  'Wichita': 1,
#  'Toledo': 5,
#  'Staten Island': 1,
#  'Des Moines': 3,
#  'Long Beach': 7,
#  'Port St. Lucie': 1,
#  'Denton': 7,
#  'Madison': 23,
#  'Reno': 4,
#  'Harrisburg': 9,
#  'Little Rock': 3,
#  'Oakland': 18,
#  'Durham': 6,
#  'Winston-Salem': 1,
#  'Bonita Springs': 1,
#  'Indio': 2,
#  'Palm Coast': 1,
#  'Chattanooga': 2,
#  'Spokane': 3,
#  'Syracuse': 7,
#  'Lancaster': 13,
#  'Arlington': 21,
#  'Stockton': 10,
#  'Poughkeepsie': 1,
#  'Augusta': 10,
#  'Boise': 1,
#  'Oxnard': 1,
#  'Scranton': 6,
#  'Modesto': 2,
#  'Kissimmee': 1,
#  'Aurora': 16,
#  'Youngstown': 3,
#  'Fayetteville': 11,
#  'Anaheim': 1,
#  'Pensacola': 2,
#  'Victorville': 1,
#  'Greensboro': 8,
#  'Corpus Christi': 1,
#  'Fort Wayne': 1,
#  'Santa Ana': 1,
#  'Flint': 1,
#  'San Juan': 3,
#  'Jackson': 16,
#  'Santa Rosa': 5,
#  'Lansing': 8,
#  'Ann Arbor': 1,
#  'Henderson': 15,
#  'Huntsville': 7,
#  'Lexington': 18,
#  'Mobile': 1,
#  'Fort Collins': 1,
#  'Asheville': 1,
#  'Santa Clarita': 1,
#  'St. Paul': 12,
#  'Antioch': 3,
#  'Lakeland': 5,
#  'Trenton': 14,
#  'Lincoln': 14,
#  'Plano': 4,
#  'Irvine': 2,
#  'Davenport': 7,
#  'Rockford': 9,
#  'Newark': 10,
#  'South Bend': 3,
#  'Shreveport': 1,
#  'Round Lake Beach': 1,
#  'Savannah': 6,
#  'Myrtle Beach': 1,
#  'Chula Vista': 4,
#  'Eugene': 2,
#  'Canton': 13,
#  'Lubbock': 1,
#  'Reading': 5,
#  'Winter Haven': 1,
#  'Salem': 21,
#  'St. Petersburg': 2,
#  'Lafayette': 10,
#  'Laredo': 2,
#  'Jersey City': 1,
#  'Chandler': 5,
#  'McKinney': 2,
#  'Scottsdale': 1,
#  'Killeen': 1,
#  'Tallahassee': 1,
#  'Peoria': 5,
#  'Wilmington': 8,
#  'Montgomery': 12,
#  'Gilbert': 7,
#  'Glendale': 11,
#  'North Las Vegas': 1,
#  'Anchorage': 2,
#  'Chesapeake': 4,
#  'Barnstable Town': 1,
#  'Norfolk': 4,
#  'Fremont': 10,
#  'Kennewick': 1,
#  'Garland': 7,
#  'Irving': 2,
#  'Visalia': 1,
#  'Atlantic City': 2,
#  'Nashua': 4,
#  'Paradise': 8,
#  'Hialeah': 1,
#  'York': 6,
#  'Evansville': 6,
#  'Avondale': 5,
#  'Brownsville': 11,
#  'Gulfport': 2,
#  'Appleton': 2,
#  'Bremerton': 1,
#  'Hickory': 5,
#  'Tacoma': 1,
#  'San Bernardino': 1,
#  'College Station': 2,
#  'Kalamazoo': 1,
#  'Thousand Oaks': 1,
#  'Roanoke': 6,
#  'Fontana': 2,
#  'Moreno Valley': 1,
#  'North Port': 1,
#  'Fargo': 4,
#  'Green Bay': 1,
#  'Amarillo': 1,
#  'Santa Barbara': 1,
#  'Gainesville': 7,
#  'Olympia': 1,
#  'Frisco': 3,
#  'Yonkers': 1,
#  'Norwich': 5,
#  'Spring Valley': 10,
#  'Huntington Beach': 1,
#  'Deltona': 1,
#  'Tempe': 1,
#  'Overland Park': 1,
#  'Grand Prairie': 1,
#  'Sunrise Manor': 1,
#  'Waco': 5,
#  'Salinas': 2,
#  'Waterbury': 3,
#  'Clarksville': 10,
#  'Cedar Rapids': 2,
#  'Sioux Falls': 1,
#  'Huntington': 9,
#  'Ontario': 5,
#  'Hagerstown': 2,
#  'Erie': 5,
#  'Vancouver': 1,
#  'Nampa': 1,
#  'Spartanburg': 1,
#  'Gastonia': 1,
#  'Fort Lauderdale': 1,
#  'Lorain': 2,
#  'Murfreesboro': 3,
#  'High Point': 2,
#  'Newport News': 1,
#  'Rancho Cucamonga': 1,
#  'Hemet': 1,
#  'Santa Cruz': 4,
#  'Danbury': 6,
#  'Oceanside': 3,
#  'Elk Grove': 1,
#  'Pembroke Pines': 1,
#  'Vallejo': 1,
#  'Garden Grove': 3,
#  'Medford': 6,
#  'Cary': 3,
#  'Marysville': 8,
#  'Corona': 3,
#  'Ocala': 1,
#  'Fredericksburg': 7,
#  'Bayamón': 2,
#  'Enterprise': 8,
#  'Manchester': 20,
#  'Champaign': 1,
#  'Alexandria': 12,
#  'Hayward': 4,
#  'Lakewood': 9,
#  'Frederick': 5,
#  'Lake Charles': 1,
#  'Odessa': 8,
#  'Tuscaloosa': 1,
#  'Warner Robins': 1,
#  'Palmdale': 2,
#  'Hollywood': 3,
#  'Midland': 11,
#  'Leesburg': 6,
#  'Port Arthur': 1,
#  'Muskegon': 1,
#  'Macon': 5,
#  'Sunnyvale': 2,
#  'Pomona': 5,
#  'Escondido': 1,
#  'Pasadena': 3,
#  'New Bedford': 3,
#  'Fairfield': 17,
#  'Naperville': 1,
#  'Bellevue': 11,
#  'Binghamton': 1,
#  'Elkhart': 5,
#  'Topeka': 3,
#  'Joliet': 2,
#  'Beaumont': 3,
#  'Paterson': 1,
#  'Merced': 1,
#  'Pueblo': 2,
#  'Tyler': 2,
#  'Torrance': 1,
#  'Metairie': 1,
#  'Yuma': 2,
#  'Surprise': 2,
#  'Athens': 12,
#  'Roseville': 7,
#  'Thornton': 7,
#  'Miramar': 1,
#  'Mesquite': 4,
#  'Santa Maria': 2,
#  'Olathe': 2,
#  'Houma': 1,
#  'Carolina': 4,
#  'Carrollton': 9,
#  'Grand Junction': 3,
#  'Orange': 6,
#  'Fullerton': 4,
#  'Greeley': 3,
#  'Las Cruces': 1,
#  'Panama City': 1,
#  'Harlingen': 2,
#  'West Valley City': 1,
#  'Hampton': 13,
#  'Warren': 10,
#  'Mauldin': 1,
#  'Bloomington': 9,
#  'Coral Springs': 1,
#  'Round Rock': 2,
#  'Yakima': 1,
#  'Sterling Heights': 1,
#  'Kent': 5,
#  'Burlington': 19,
#  'Bellingham': 3,
#  'Santa Clara': 5,
#  'Racine': 4,
#  'Stamford': 4,
#  'Elizabeth': 8,
#  'Johnson City': 5,
#  'Lynchburg': 5,
#  'Simi Valley': 1,
#  'Fort Smith': 2,
#  'Kenosha': 1,
#  'South Lyon': 1,
#  'Boulder': 4,
#  'Pearland': 1,
#  'Berkeley': 3,
#  'Richardson': 1,
#  'Redding': 2,
#  'Arvada': 2,
#  'St. George': 6,
#  'Billings': 3,
#  'Yuba City': 1,
#  'East Los Angeles': 1,
#  'Leominster': 1,
#  'Kingsport': 1,
#  'Duluth': 3,
#  'Lehigh Acres': 1,
#  'Rock Hill': 4,
#  'Gilroy': 1,
#  'Cambridge': 13,
#  'Sugar Land': 1,
#  'Texas City': 1,
#  'Iowa City': 1,
#  'Saginaw': 3,
#  'Chico': 3,
#  'Dover': 16,
#  'Norman': 4,
#  'Clearwater': 5,
#  "Coeur d'Alene": 1,
#  'Ponce': 1,
#  'Seaside': 2,
#  'Independence': 12,
#  'West Jordan': 1,
#  'Abilene': 2,
#  'El Monte': 1,
#  'Carlsbad': 3,
#  'North Charleston': 1,
#  'St. Cloud': 4,
#  'Temecula': 1,
#  'Clovis': 2,
#  'Meridian': 8,
#  'Brandon': 8,
#  'Westminster': 8,
#  'Costa Mesa': 1,
#  'Monroe': 16,
#  'Utica': 13,
#  'Pompano Beach': 1,
#  'West Palm Beach': 1,
#  'Waterloo': 10,
#  'Everett': 3,
#  'El Centro': 1,
#  'Santa Fe': 2,
#  'Downey': 2,
#  'Lowell': 10,
#  'Centennial': 2,
#  'Elgin': 15,
#  'Broken Arrow': 1,
#  'Miami Gardens': 1,
#  'The Woodlands': 1,
#  'Bend': 2,
#  'Jurupa Valley': 1,
#  'Sandy Springs': 1,
#  'Gresham': 3,
#  'Lewisville': 8,
#  'Hillsboro': 17,
#  'San Buenaventura': 1,
#  'Pottstown': 1,
#  'Inglewood': 2,
#  'Spring Hill': 7,
#  'League City': 1,
#  'Eau Claire': 3,
#  'Turlock': 1,
#  'Temple': 4,
#  'Sioux City': 1,
#  'Salisbury': 6,
#  'Davie': 1,
#  'Daly City': 1,
#  'Allen': 8,
#  'Highlands Ranch': 1,
#  'West Covina': 1,
#  'Sparks': 4,
#  'San Mateo': 2,
#  'Norwalk': 5,
#  'Rialto': 1,
#  'Manteca': 1,
#  'El Cajon': 1,
#  'Burbank': 6,
#  'Longmont': 1,
#  'Renton': 1,
#  'Vista': 2,
#  'Logan': 8,
#  'Prescott Valley': 1,
#  'Vacaville': 1,
#  'Edinburg': 5,
#  'Carmel': 1,
#  'Spokane Valley': 1,
#  'San Angelo': 1,
#  'La Crosse': 5,
#  'Arden-Arcade': 1,
#  'Idaho Falls': 1,
#  'Holland': 10,
#  'Charlottesville': 1,
#  'Longview': 3,
#  'Tracy': 3,
#  'Boca Raton': 1,
#  'Wichita Falls': 1,
#  'Rio Rancho': 1,
#  'South Fulton': 2,
#  'Beaverton': 3,
#  'Lawrence': 7,
#  'Bismarck': 3,
#  'Orem': 1,
#  'Middletown': 15,
#  'San Marcos': 2,
#  'Sandy': 3,
#  'Federal Way': 1,
#  'Mandeville': 1,
#  'Hesperia': 2,
#  'Brockton': 2,
#  'Compton': 2,
#  'Fishers': 1,
#  'Sunrise': 2,
#  'Bowling Green': 6,
#  'Roswell': 4,
#  'Menifee': 2,
#  'Plantation': 3,
#  'Quincy': 7,
#  'Portsmouth': 4,
#  'Chino': 1,
#  'Lynn': 5,
#  'Edmond': 2,
#  'Hanford': 1,
#  'Dearborn': 2,
#  'Livonia': 5,
#  'South Gate': 1,
#  'Vineland': 3,
#  'San Tan Valley': 1,
#  'Florence': 16,
#  'Slidell': 1,
#  'Kirkland': 2,
#  'Missoula': 1,
#  'Auburn': 17,
#  'Rapid City': 2,
#  "Lee's Summit": 1,
#  'Terre Haute': 1,
#  'Suffolk': 1,
#  'Blacksburg': 2,
#  'Mount Pleasant': 11,
#  'Carson': 4,
#  'Riverview': 7,
#  'Conroe': 1,
#  'Livermore': 3,
#  'Germantown': 7,
#  'Lawton': 4,
#  'Santa Monica': 2,
#  'New Braunfels': 1,
#  'Fall River': 3,
#  'Miami Beach': 1,
#  'San Leandro': 1,
#  'Toms River': 1,
#  "O'Fallon": 2,
#  'Alafaya': 1,
#  'Newton': 11,
#  'Muncie': 2,
#  'Citrus Heights': 1,
#  'State College': 1,
#  'Decatur': 10,
#  'Fort Myers': 1,
#  'Goodyear': 1,
#  'Dalton': 8,
#  'Bryan': 2,
#  'Waukegan': 1,
#  'Hawthorne': 5,
#  'Anderson': 10,
#  'Redwood City': 1,
#  'Hoover': 1,
#  "Town 'n' Country": 1,
#  'Lake Forest': 2,
#  'Napa': 1,
#  'Whittier': 2,
#  'Clifton': 11,
#  'Largo': 2,
#  'Johns Creek': 1,
#  'Newport Beach': 1,
#  'Mission': 4,
#  'Milpitas': 1,
#  'Troy': 17,
#  'Madera': 1,
#  'Joplin': 2,
#  'Chino Hills': 1,
#  'Alhambra': 2,
#  'Franklin': 30,
#  'Melbourne': 4,
#  'Port Huron': 1,
#  'Mountain View': 11,
#  'Zephyrhills': 1,
#  'St. Augustine': 2,
#  'Flagstaff': 1,
#  'Buena Park': 1,
#  'Pleasanton': 6,
#  'Westland': 2,
#  'Cranston': 1,
#  'Somerville': 7,
#  'Folsom': 5,
#  'Springdale': 10,
#  'Deerfield Beach': 1,
#  'Warwick': 5,
#  'Cicero': 2,
#  'Farmington Hills': 1,
#  'Williamsburg': 9,
#  'Brooklyn Park': 2,
#  'Hattiesburg': 1,
#  'Valdosta': 1,
#  'Plymouth': 14,
#  'Silver Spring': 1,
#  'Buckeye': 2,
#  'Georgetown': 22,
#  'Cheyenne': 2,
#  'Cedar Park': 1,
#  'Kokomo': 1,
#  'Tustin': 3,
#  'Perris': 1,
#  'St. Joseph': 8,
#  'Flower Mound': 1,
#  'Pharr': 1,
#  'Atascocita': 1,
#  'Alton': 8,
#  'Loveland': 4,
#  'Boynton Beach': 1,
#  'New Rochelle': 1,
#  'Lebanon': 16,
#  'Parma': 4,
#  'Layton': 2,
#  'Elizabethtown': 7,
#  'Texarkana': 2,
#  'Alameda': 1,
#  'The Villages': 1,
#  'Kankakee': 1,
#  'Watsonville': 1,
#  'Porterville': 1,
#  'Baytown': 1,
#  'Upland': 4,
#  'Davis': 6,
#  'Camarillo': 1,
#  'South Jordan': 1,
#  'Battle Creek': 3,
#  'Bellflower': 3,
#  'Jonesboro': 5,
#  'San Ramon': 1,
#  'Lake Jackson': 1,
#  'Bethlehem': 5,
#  'Wyoming': 9,
#  'Pine Hills': 2,
#  'Oshkosh': 2,
#  'Hammond': 6,
#  'Missouri City': 2,
#  'Centreville': 6,
#  'Pasco': 1,
#  'Wheeling': 3,
#  'Baldwin Park': 2,
#  'Rancho Cordova': 1,
#  'Caguas': 1,
#  'Conway': 11,
#  'Gary': 4,
#  'Altoona': 7,
#  'Lodi': 5,
#  'Arlington Heights': 4,
#  'Kendall': 3,
#  'Waldorf': 2,
#  'Bolingbrook': 1,
#  'Rochester Hills': 1,
#  'Winchester': 16,
#  'Framingham': 1,
#  'Hilton Head Island': 1,
#  'Union City': 9,
#  'Owensboro': 1,
#  'Cheektowaga': 1,
#  'Wausau': 2,
#  'Camden': 14,
#  'Dale City': 1,
#  'Anniston': 2,
#  'Evanston': 2,
#  'Apple Valley': 4,
#  'Mansfield': 10,
#  'Schaumburg': 1,
#  'Pocatello': 1,
#  'Woodbury': 8,
#  'Southfield': 1,
#  'Maple Grove': 2,
#  'Pittsburg': 5,
#  'New Britain': 2,
#  'Morgantown': 5,
#  'Dothan': 1,
#  'Harrisonburg': 2,
#  'Wenatchee': 1,
#  'Waukesha': 1,
#  'Ellicott City': 1,
#  'Pawtucket': 1,
#  'Redmond': 3,
#  'Lauderhill': 1,
#  'Sumter': 1,
#  'Redlands': 2,
#  'Daphne': 1,
#  'Mount Vernon': 16,
#  'Weston': 13,
#  'St. Charles': 10,
#  'Janesville': 4,
#  'Sherman': 5,
#  'North Richland Hills': 1,
#  'Broomfield': 1,
#  'El Paso de Robles': 1,
#  'Bristol': 11,
#  'Walnut Creek': 4,
#  'Lynwood': 2,
#  'Glen Burnie': 1,
#  'Lehi': 1,
#  'Passaic': 2,
#  'Guaynabo': 1,
#  'Casas Adobes': 1,
#  'Homestead': 5,
#  'West Bend': 2,
#  'Delray Beach': 1,
#  'Sheboygan': 1,
#  'Lake Elsinore': 1,
#  'Daytona Beach': 1,
#  'Los Lunas': 1,
#  'Lima': 6,
#  'Rocklin': 1,
#  'Rogers': 6,
#  'Castle Rock': 2,
#  'Hanover': 11,
#  'Bossier City': 1,
#  'Dubuque': 1,
#  'Rockville': 9,
#  'Victoria': 6,
#  'Saratoga Springs': 2,
#  'Gaithersburg': 1,
#  'Ames': 5,
#  'West Des Moines': 1,
#  'South San Francisco': 1,
#  'Yorba Linda': 1,
#  'Casper': 1,
#  'Palatine': 1,
#  'Corvallis': 2,
#  'Ankeny': 1,
#  'Rowlett': 1,
#  'Lakeville': 4,
#  'Alpharetta': 1,
#  'Poinciana': 1,
#  'DeKalb': 1,
#  'Petaluma': 1,
#  'Redondo Beach': 1,
#  'Tamarac': 1,
#  'Laguna Niguel': 1,
#  'Eagan': 1,
#  'Kenner': 1,
#  'Bay City': 4,
#  'North Little Rock': 1,
#  'Sammamish': 1,
#  'Shawnee': 4,
#  'Jupiter': 1,
#  'Doral': 1,
#  'Carbondale': 4,
#  'Blaine': 5,
#  'Weirton': 1,
#  'Tulare': 2,
#  'Wellington': 9,
#  'Pflugerville': 1,
#  'Palo Alto': 2,
#  'Schenectady': 1,
#  'Great Falls': 3,
#  'Michigan City': 2,
#  'Bayonne': 1,
#  'Eden Prairie': 1,
#  'Port Orange': 1,
#  'Dublin': 8,
#  'Carmichael': 1,
#  'Grand Forks': 1,
#  'Noblesville': 1,
#  'San Clemente': 1,
#  'Brentwood': 6,
#  'East Orange': 1,
#  'Florence-Graham': 1,
#  'Eastvale': 2,
#  'Chapel Hill': 2,
#  'Rocky Mount': 2,
#  'Haverhill': 3,
#  'Beloit': 3,
#  'Glens Falls': 1,
#  'Castro Valley': 1,
#  'Fairbanks': 1,
#  'Johnstown': 6,
#  'West Hartford': 1,
#  'Coon Rapids': 2,
#  'Elmira': 3,
#  'Mankato': 2,
#  'North Miami': 2,
#  'Dundalk': 1,
#  'Encinitas': 1,
#  'Skokie': 1,
#  'Leander': 1,
#  'Mayagüez': 1,
#  'Parkersburg': 3,
#  'Waltham': 2,
#  'Bethesda': 2,
#  'San Luis Obispo': 1,
#  'Sebring': 2,
#  'Council Bluffs': 1,
#  'Hamilton': 16,
#  'Moore': 4,
#  'Pico Rivera': 1,
#  'Palm Harbor': 1,
#  'Casa Grande': 1,
#  'Monessen': 1,
#  'Montebello': 2,
#  'Rome': 7,
#  'Millcreek': 1,
#  'Sanford': 8,
#  'National City': 1,
#  'Burnsville': 4,
#  'Coconut Creek': 1,
#  'Port Charlotte': 1,
#  'Morristown': 8,
#  'Gadsden': 4,
#  'Taylor': 11,
#  'Novi': 1,
#  'Marietta': 10,
#  'Hot Springs': 5,
#  'Woodland': 12,
#  'La Habra': 1,
#  'The Hammocks': 1,
#  'Malden': 4,
#  'Commerce City': 1,
#  'Reston': 1,
#  'South Whittier': 1,
#  'West Allis': 1,
#  'Fountainebleau': 1,
#  'Taylorsville': 7,
#  'Bangor': 5,
#  'Monterey Park': 2,
#  'Greenwood': 13,
#  'Bartlett': 7,
#  'Bradenton': 1,
#  'Pontiac': 3,
#  'Staunton': 3,
#  'Meriden': 3,
#  'Gardena': 2,
#  'Apex': 1,
#  'Royal Oak': 1,
#  'Cupertino': 1,
#  'La Mesa': 2,
#  'Brookline': 1,
#  'Benton Harbor': 1,
#  'St. Clair Shores': 1,
#  'Des Plaines': 1,
#  'Lewiston': 8,
#  'Margate': 1,
#  'Spring': 1,
#  'Carson City': 2,
#  'Bowie': 3,
#  'Caldwell': 6,
#  'San Rafael': 2,
#  'Kendale Lakes': 1,
#  'Towson': 1,
#  'Richland': 12,
#  'St. Peters': 1,
#  'South Hill': 3,
#  'Hendersonville': 3,
#  'White Plains': 5,
#  'Huntersville': 2,
#  'Santee': 3,
#  'Jefferson City': 3,
#  'Beckley': 1,
#  'Arcadia': 13,
#  'Titusville': 3,
#  'Cartersville': 1,
#  'Walla Walla': 1,
#  'Orland Park': 1,
#  'Weymouth Town': 1,
#  'Parker': 10,
#  'Palm Beach Gardens': 1,
#  'Bozeman': 1,
#  'East Stroudsburg': 1,
#  'Tamiami': 1,
#  'Huntington Park': 1,
#  'Taunton': 2,
#  'Midwest City': 1,
#  'Goldsboro': 3,
#  'Euless': 1,
#  'Shoreline': 1,
#  'Lake Havasu City': 1,
#  'Smyrna': 5,
#  'Cape Girardeau': 1,
#  'Grants Pass': 1,
#  'Blue Springs': 4,
#  'Southaven': 1,
#  'Tinley Park': 1,
#  'Diamond Bar': 1,
#  'Pittsfield': 4,
#  'Eagle Pass': 1,
#  'New Brunswick': 1,
#  'Lenexa': 1,
#  'Hazleton': 3,
#  'Twin Falls': 1,
#  'Brookhaven': 5,
#  'Novato': 1,
#  'Tigard': 1,
#  'Aloha': 1,
#  'Highland': 11,
#  'Fountain Valley': 1,
#  'Dearborn Heights': 1,
#  'Grapevine': 1,
#  'Fond du Lac': 1,
#  'Ithaca': 4,
#  'Chicopee': 2,
#  'Hempstead': 2,
#  'Wesley Chapel': 2,
#  'Oak Lawn': 1,
#  'Cathedral City': 1,
#  'Hacienda Heights': 1,
#  'Delano': 3,
#  'Bentonville': 2,
#  'Stonecrest': 1,
#  'Kettering': 2,
#  'Colton': 4,
#  'Kingston': 18,
#  'West Haven': 2,
#  'Normal': 1,
#  'Berwyn': 3,
#  'Arroyo Grande': 1,
#  'Minnetonka': 1,
#  'Rosemead': 1,
#  'Paramount': 1,
#  'Yucaipa': 1,
#  'Brunswick': 7,
#  'Williamsport': 4,
#  'Elyria': 2,
#  'Mount Prospect': 1,
#  'Pinellas Park': 1,
#  'West Sacramento': 1,
#  'Apopka': 1,
#  'Grand Island': 1,
#  'Palm Desert': 1,
#  'Milford city ': 1,
#  'Watertown': 7,
#  'Little Elm': 1,
#  'Chambersburg': 1,
#  'Revere': 3,
#  'Peabody': 2,
#  'Wylie': 1,
#  'Beaufort': 2,
#  'DeSoto': 1,
#  'Helena': 5,
#  'Edina': 2,
#  'Aspen Hill': 1,
#  'Wheaton': 5,
#  'West New York': 1,
#  'Hoboken': 2,
#  'Lacey': 1,
#  'Summerville': 4,
#  'Oak Park': 4,
#  'Lompoc': 1,
#  'Kentwood': 2,
#  'Sierra Vista': 1,
#  'Levittown': 2,
#  'Glendora': 3,
#  'Burien': 1,
#  'Perth Amboy': 1,
#  'Herriman': 1,
#  'Farmington': 17,
#  'New Bern': 1,
#  'Placentia': 1,
#  'Hinesville': 1,
#  'Collierville': 2,
#  'West Lafayette': 2,
#  'Florissant': 2,
#  'Hoffman Estates': 1,
#  'Queen Creek': 1,
#  'Aliso Viejo': 1,
#  'Kannapolis': 1,
#  'Maricopa': 2,
#  'Methuen Town': 1,
#  'Sahuarita': 1,
#  'Rowland Heights': 1,
#  'Traverse City': 1,
#  'East Hartford': 1,
#  'Irondequoit': 1,
#  'Catalina Foothills': 1,
#  'Cookeville': 1,
#  'Mishawaka': 1,
#  'Plainfield': 9,
#  'Bullhead City': 1,
#  'Ashburn': 3,
#  'North Bethesda': 1,
#  'Forney': 1,
#  'Severn': 2,
#  'Azusa': 1,
#  'Cerritos': 1,
#  'Bloomsburg': 1,
#  'Morehead City': 1,
#  'Coral Gables': 1,
#  'Country Club': 3,
#  'Oroville': 2,
#  'Wilson': 11,
#  'Portage': 6,
#  'Minot': 1,
#  'Dunwoody': 1,
#  'Poway': 1,
#  'San Jacinto': 1,
#  'Florin': 1,
#  'Cuyahoga Falls': 1,
#  'Downers Grove': 1,
#  'Bedford': 9,
#  'Reedley': 1,
#  'Marana': 1,
#  'Stillwater': 4,
#  'Cypress': 2,
#  'Hollister': 5,
#  'North Highlands': 1,
#  'Murray': 4,
#  'Pascagoula': 1,
#  'Ceres': 1,
#  'St. Louis Park': 1,
#  'Rio Grande City': 1,
#  'Draper': 3,
#  'Palm Springs': 2,
#  'Paducah': 2,
#  'Findlay': 2,
#  'Kyle': 2,
#  'Tuckahoe': 3,
#  'Bel Air South': 1,
#  'Ocoee': 1,
#  'Burleson': 1,
#  'La Mirada': 1,
#  'Farmers Branch': 1,
#  'East Lansing': 1,
#  'Uniontown': 6,
#  'Jeffersonville': 7,
#  'Winder': 1,
#  'Wauwatosa': 1,
#  'Littleton': 5,
#  'Cumberland': 7,
#  'Cedar Hill': 4,
#  'Enid': 1,
#  'Rancho Santa Margarita': 1,
#  'East Honolulu': 1,
#  'Beavercreek': 2,
#  'Niagara Falls': 1,
#  'East Providence': 1,
#  'Chesterfield': 5,
#  'Covina': 1,
#  'Bothell': 1,
#  'Antelope': 4,
#  'Glenview': 2,
#  'Mentor': 3,
#  'Keller': 3,
#  'McLean': 4,
#  'Danville': 16,
#  'Elmhurst': 1,
#  'New Philadelphia': 2,
#  'Sandusky': 2,
#  'Euclid': 1,
#  'Kingman': 3,
#  'Galveston': 2,
#  'University': 3,
#  ...}

# %%
# import plotly
# import plotly_express as px
# import pandas as pd 
# import plotly.graph_objects as go
# import dash
# import dash_core_components as dcc
# import dash_html_components as html 
# from dash.dependencies import Input, Output


# df = pd.read_csv('weather_lat_long.csv')
# # print(df.head)
# # city_state = df['City_State'].drop_duplicates().to_list()
# # subset = df[df.City == 'Alpharetta']
# # f = subset.groupby(['month'], as_index=False).mean()
# # # print(f) 
# # figs = []
# # for city in city_state:
# #   subset = df[df.City_State == city]
# #   f = subset.groupby(['month'], as_index=False).mean()
# #   fig = px.line(f, x='month', y=['MinTempF', 'MaxTempF'])
# #   fig.update_layout(title=df['City_State'].iloc[0])
# #   figs.append(fig)
# # for fig in figs:
# #   fig
# # print(figs[1])
# # f.reset_index(inplace=True)


# app = dash.Dash(__name__)

# app.layout = html.Div([
#     html.H1("Weather Data Dashboard with Dash", style={'text-align': 'center'}),

#     dcc.Dropdown(id="slct_year",
#                  options=[
#                           {"label": "2015", "value": 2015},
#                           {"label": "2016", "value": 2016},
#                           {"label": "2017", "value": 2017},
#                           {"label": "2018", "value": 2018},
#                           {"label": "2019", "value": 2019}],
#                  multi=False,
#                  value=2015,
#                  style={'width': "40%"}
#                  ),
#     html.Div(id='output_container', children=[]),
#     html.Br(),

#     dcc.Graph(id='my_bee_map', figure={})
# ])



# # Connects the plotly grpahs with Dash Components
# @app.callback(
#     [Output(component_id='output_container', component_property='children'),
#     Output(component_id='my_bee_map', component_property='figure')],
#     [Input(component_id='slct_year', component_property='value')]
# )
# def update_graph(option_slctd):
#     print(option_slctd)
#     #print(type(option_slctd))

#     container = "The year chosen by user was: {}".format(option_slctd)

#     dff = df.copy()
#     dff = dff[dff["year"] == option_slctd]
#     dff = dff[dff["city"] == dff["city"]]

#     #Plotly Express
#     big = px.choropleth(
#         data_frame=dff,
#         locationmode='USA-states',
#         locations='city_postal',
#         scope="usa",
#         color='FeelsLikeF',
#         hover_data=['City', 'FeelsLikeF', 'lat', 'lng'],
#         color_continuous_scale=px.colors.sequential.YlOrRd,
#         labels={'FeelsLikeF': '% Temperature Feels Like'},
#         template='plotly_dark'
#     )





#     return container, big


# #-------------------------------------------------------------------------
# if __name__ == '__main__':
#   app.run_server(debug=True, use_reloader=False)
